# %%
import numpy as np
from tensorflow import set_random_seed
from numpy.random import seed
import pandas as pd
#import matplotlib.pyplot as plt
from keras import optimizers
from keras.callbacks import ModelCheckpoint
from keras.utils import plot_model
from keras.models import Sequential, Model
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers import Dense, LSTM, RepeatVector, TimeDistributed, Flatten, Dropout
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from datetime import datetime
from datetime import timedelta
# Out:
# Using TensorFlow backend.

# %%
#dataset_empty = 0
set_random_seed(1)
seed(1)

# %%
#Convert the train data into time series
def time_series_data(data, window, lag):
    dropnan = True
    cols, names = list(), list()

    for i in range(window, 0, -1):
        #past time series data (t-)
        cols.append(data.shift(i))
        names = names + [('%s(t-%d)' % (col, i)) for col in data.columns]
    
    #current time series data (t = 0)
    cols.append(data)
    names = names + [('%s(t)' % (col)) for col in data.columns]
    
    #future data (t + lag)
    cols.append(data.shift(-lag))
    names = names + [('%s(t+%d)' % (col, lag)) for col in data.columns]
    
    #all data
    all_data = pd.concat(cols, axis=1)
    all_data.columns = names
    
    #drops rows with NaN
    if dropnan:
        all_data.dropna(inplace=True)
    return all_data

# %%
dataset = pd.read_csv('sales data-set.csv', usecols = ['Store', 'Item', 'Date', 'Weekly_Sales'])
train = dataset[['Store', 'Item', 'Date', 'Weekly_Sales']]
#train = train.loc[(train['Store'] == 1) & (train['Item'] == 1)]
#train = train[(train['Date'] >= '2012-01-01')]
train = train.loc[train['Store'] == 1]

print(train.head())
# Out:
#    Store  Item        Date  Weekly_Sales
# 0      1     1  2010-02-07      24924.50
# 1      1     2  2010-02-07      50605.27
# 2      1     3  2010-02-07      13740.12
# 3      1     4  2010-02-07      39954.04
# 4      1     5  2010-02-07      32229.38

# %%
#Re-arranges the train dataset to apply shift methods
train_r = train.sort_values('Date').groupby(['Item', 'Store', 'Date'], as_index=False)
train_r = train_r.agg({'Weekly_Sales':['mean']})
train_r.columns = ['Item', 'Store', 'Date', 'Weekly_Sales']
#cols_to_drop = ['Date']
#train_r.drop(cols_to_drop, axis=1, inplace=True)
train_r.head()
# Out:
#    Item  Store        Date  Weekly_Sales
# 0     1      1  2010-02-07      24924.50
# 1     1      1  2010-02-14      46039.49
# 2     1      1  2010-02-21      41595.55
# 3     1      1  2010-02-28      19403.54
# 4     1      1  2010-03-07      21827.90

# %%
train_r = train_r.groupby(['Date'], as_index=False)['Weekly_Sales'].sum()
train_r.head()
# Out:
#          Date  Weekly_Sales
# 0  2010-02-07    1643690.90
# 1  2010-02-14    1641957.44
# 2  2010-02-21    1611968.17
# 3  2010-02-28    1409727.59
# 4  2010-03-07    1554806.68

# %%
#weekly sales in 10 million dollars
train_r['Weekly_Sales'] = round(train_r['Weekly_Sales'] / 1000000, 2)
train_r.head()
# Out:
#          Date  Weekly_Sales
# 0  2010-02-07          1.64
# 1  2010-02-14          1.64
# 2  2010-02-21          1.61
# 3  2010-02-28          1.41
# 4  2010-03-07          1.55

# %%
#the model will use last 117 weekly sales data and 
#current timestep (7 days) to forecast next weekly sales data 12 weeks ahead

#the model will use last 29 weekly sales data and 
#current timestep (7 days) to forecast next weekly sales data 4 weeks ahead

window = 117
lag = 12

series_data = time_series_data(train_r, window, lag)
series_data.head()
# Out:
#     Date(t-117)  Weekly_Sales(t-117) Date(t-116)  Weekly_Sales(t-116)  \
# 117  2010-02-07                 1.64  2010-02-14                 1.64
# 118  2010-02-14                 1.64  2010-02-21                 1.61
# 119  2010-02-21                 1.61  2010-02-28                 1.41
# 120  2010-02-28                 1.41  2010-03-07                 1.55
# 121  2010-03-07                 1.55  2010-03-14                 1.44
#
#     Date(t-115)  Weekly_Sales(t-115) Date(t-114)  Weekly_Sales(t-114)  \
# 117  2010-02-21                 1.61  2010-02-28                 1.41
# 118  2010-02-28                 1.41  2010-03-07                 1.55
# 119  2010-03-07                 1.55  2010-03-14                 1.44
# 120  2010-03-14                 1.44  2010-03-21                 1.47
# 121  2010-03-21                 1.47  2010-03-28                 1.40
#
#     Date(t-113)  Weekly_Sales(t-113)  ...   Date(t-3)  Weekly_Sales(t-3)  \
# 117  2010-03-07                 1.55  ...  2012-04-15               1.62
# 118  2010-03-14                 1.44  ...  2012-04-22               1.52
# 119  2010-03-21                 1.47  ...  2012-04-29               1.47
# 120  2010-03-28                 1.40  ...  2012-05-06               1.68
# 121  2010-04-04                 1.59  ...  2012-05-13               1.61
#
#       Date(t-2)  Weekly_Sales(t-2)   Date(t-1)  Weekly_Sales(t-1)     Date(t)  \
# 117  2012-04-22               1.52  2012-04-29               1.47  2012-05-06
# 118  2012-04-29               1.47  2012-05-06               1.68  2012-05-13
# 119  2012-05-06               1.68  2012-05-13               1.61  2012-05-20
# 120  2012-05-13               1.61  2012-05-20               1.60  2012-05-27
# 121  2012-05-20               1.60  2012-05-27               1.56  2012-06-03
#
#      Weekly_Sales(t)  Date(t+12)  Weekly_Sales(t+12)
# 117             1.68  2012-07-29                1.44
# 118             1.61  2012-08-05                1.63
# 119             1.60  2012-08-12                1.59
# 120             1.56  2012-08-19                1.60
# 121             1.62  2012-08-26                1.49
#
# [5 rows x 238 columns]

# %%
future_dates = series_data[['Date(t+%d)' % lag]]
future_dates
# Out:
#      Date(t+12)
# 117  2012-07-29
# 118  2012-08-05
# 119  2012-08-12
# 120  2012-08-19
# 121  2012-08-26
# 122  2012-09-02
# 123  2012-09-09
# 124  2012-09-16
# 125  2012-09-23
# 126  2012-09-30
# 127  2012-10-07
# 128  2012-10-14
# 129  2012-10-21
# 130  2012-10-28

# %%
#drops last record of (t + lag)
#last_record_item = 'Item(t-%d)' % window
#last_record_store = 'Store(t-%d)' % window
#series_data = series_data[(series_data['Item(t)'] == series_data[last_record_item])]
#series_data = series_data[(series_data['Store(t)'] == series_data[last_record_store])]

#drops Item and Store columns
cols_to_drop = [('%s(t+%d)' % (col, lag)) for col in ['Date']]
for i in range(window, 0, -1):
    cols_to_drop += [('%s(t-%d)' % (col, i)) for col in ['Date']]

series_data.drop(cols_to_drop, axis=1, inplace=True)
series_data.drop(['Date(t)'], axis=1, inplace=True)

lbls_col = 'Weekly_Sales(t+%d)' % lag
lbls = series_data[lbls_col]
series_data = series_data.drop(lbls_col, axis=1)

series_data.head()
# Out:
#      Weekly_Sales(t-117)  Weekly_Sales(t-116)  Weekly_Sales(t-115)  \
# 117                 1.64                 1.64                 1.61
# 118                 1.64                 1.61                 1.41
# 119                 1.61                 1.41                 1.55
# 120                 1.41                 1.55                 1.44
# 121                 1.55                 1.44                 1.47
#
#      Weekly_Sales(t-114)  Weekly_Sales(t-113)  Weekly_Sales(t-112)  \
# 117                 1.41                 1.55                 1.44
# 118                 1.55                 1.44                 1.47
# 119                 1.44                 1.47                 1.40
# 120                 1.47                 1.40                 1.59
# 121                 1.40                 1.59                 1.55
#
#      Weekly_Sales(t-111)  Weekly_Sales(t-110)  Weekly_Sales(t-109)  \
# 117                 1.47                 1.40                 1.59
# 118                 1.40                 1.59                 1.55
# 119                 1.59                 1.55                 1.47
# 120                 1.55                 1.47                 1.39
# 121                 1.47                 1.39                 1.43
#
#      Weekly_Sales(t-108)  ...  Weekly_Sales(t-9)  Weekly_Sales(t-8)  \
# 117                 1.55  ...               1.69               1.68
# 118                 1.47  ...               1.68               1.68
# 119                 1.39  ...               1.68               1.51
# 120                 1.43  ...               1.51               1.65
# 121                 1.60  ...               1.65               1.90
#
#      Weekly_Sales(t-7)  Weekly_Sales(t-6)  Weekly_Sales(t-5)  \
# 117               1.68               1.51               1.65
# 118               1.51               1.65               1.90
# 119               1.65               1.90               1.62
# 120               1.90               1.62               1.52
# 121               1.62               1.52               1.47
#
#      Weekly_Sales(t-4)  Weekly_Sales(t-3)  Weekly_Sales(t-2)  \
# 117               1.90               1.62               1.52
# 118               1.62               1.52               1.47
# 119               1.52               1.47               1.68
# 120               1.47               1.68               1.61
# 121               1.68               1.61               1.60
#
#      Weekly_Sales(t-1)  Weekly_Sales(t)
# 117               1.47             1.68
# 118               1.68             1.61
# 119               1.61             1.60
# 120               1.60             1.56
# 121               1.56             1.62
#
# [5 rows x 118 columns]

# %%
series_data.shape[0]
# Out:
# 14

# %%
#train and test split

X_train_1, X_test_1, Y_train_1, Y_test_1 = train_test_split(series_data, lbls.values, test_size=0.1, random_state=0)
X_train = X_train_1
Y_train = Y_train_1

X_train_1, X_test_1, Y_train_1, Y_test_1 = train_test_split(series_data, lbls.values, test_size=0.5, random_state=0)
X_test = X_test_1
Y_test = Y_test_1

print('Train dataset:', X_train.shape)
print('Test dataset:', X_test.shape)
X_train.head()
# Out:
# Train dataset: (12, 118)
# Test dataset: (7, 118)
#      Weekly_Sales(t-117)  Weekly_Sales(t-116)  Weekly_Sales(t-115)  \
# 121                 1.55                 1.44                 1.47
# 128                 1.39                 1.43                 1.60
# 119                 1.61                 1.41                 1.55
# 130                 1.60                 1.49                 1.40
# 126                 1.55                 1.47                 1.39
#
#      Weekly_Sales(t-114)  Weekly_Sales(t-113)  Weekly_Sales(t-112)  \
# 121                 1.40                 1.59                 1.55
# 128                 1.49                 1.40                 1.43
# 119                 1.44                 1.47                 1.40
# 130                 1.43                 1.62                 1.54
# 126                 1.43                 1.60                 1.49
#
#      Weekly_Sales(t-111)  Weekly_Sales(t-110)  Weekly_Sales(t-109)  \
# 121                 1.47                 1.39                 1.43
# 128                 1.62                 1.54                 1.50
# 119                 1.59                 1.55                 1.47
# 130                 1.50                 1.42                 1.49
# 126                 1.40                 1.43                 1.62
#
#      Weekly_Sales(t-108)  ...  Weekly_Sales(t-9)  Weekly_Sales(t-8)  \
# 121                 1.60  ...               1.65               1.90
# 128                 1.42  ...               1.60               1.56
# 119                 1.39  ...               1.68               1.51
# 130                 1.55  ...               1.62               1.70
# 126                 1.54  ...               1.68               1.61
#
#      Weekly_Sales(t-7)  Weekly_Sales(t-6)  Weekly_Sales(t-5)  \
# 121               1.62               1.52               1.47
# 128               1.62               1.70               1.63
# 119               1.65               1.90               1.62
# 130               1.63               1.53               1.54
# 126               1.60               1.56               1.62
#
#      Weekly_Sales(t-4)  Weekly_Sales(t-3)  Weekly_Sales(t-2)  \
# 121               1.68               1.61               1.60
# 128               1.53               1.54               1.77
# 119               1.52               1.47               1.68
# 130               1.77               1.53               1.50
# 126               1.70               1.63               1.53
#
#      Weekly_Sales(t-1)  Weekly_Sales(t)
# 121               1.56             1.62
# 128               1.53             1.50
# 119               1.61             1.60
# 130               1.44             1.63
# 126               1.54             1.77
#
# [5 rows x 118 columns]

# %%
X_train_series = X_train.values.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_series = X_test.values.reshape((X_test.shape[0], X_test.shape[1], 1))
print('Train dataset:', X_train_series.shape)
print('Test dataset:', X_test_series.shape)
# Out:
# Train dataset: (12, 118, 1)
# Test dataset: (7, 118, 1)

# %%
#CNN-LSTM
subsequences = 2
time_steps = X_train_series.shape[1] // subsequences
X_train_series_sub = X_train_series.reshape((X_train_series.shape[0], subsequences, time_steps, 1))
X_test_series_sub = X_test_series.reshape((X_test_series.shape[0], subsequences, time_steps, 1))
print('Train dataset:', X_train_series_sub.shape)
print('Test dataset:', X_test_series_sub.shape)
# Out:
# Train dataset: (12, 2, 59, 1)
# Test dataset: (7, 2, 59, 1)

# %%
epochs = 2000
batch = 32
learning_rate = 0.00000001
adam = optimizers.Adam(learning_rate)

# %%
model_cnn_lstm = Sequential()
model_cnn_lstm.add(TimeDistributed(Conv1D(filters = 64, kernel_size = 1, activation = 'relu'), input_shape = (None, X_train_series_sub.shape[2], X_train_series_sub.shape[3])))
model_cnn_lstm.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model_cnn_lstm.add(TimeDistributed(Flatten()))
model_cnn_lstm.add(LSTM(60, activation = 'relu'))
model_cnn_lstm.add(Dropout(0.1))
#model_cnn_lstm.add(Dense(100, activation='relu'))
#model_cnn_lstm.add(Dropout(0.4))
#model_cnn_lstm.add(Dense(50, activation='relu'))
#model_cnn_lstm.add(Dropout(0.3))
#model_cnn_lstm.add(Dense(32, activation='relu'))
#model_cnn_lstm.add(Dense(16, activation='relu'))
model_cnn_lstm.add(Dense(30, activation = 'relu'))
model_cnn_lstm.add(Dropout(0.1))
model_cnn_lstm.add(Dense(1))
model_cnn_lstm.compile(loss = 'mse', optimizer = 'adam')
model_cnn_lstm.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_4 (TimeDist (None, None, 59, 64)      128
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, None, 29, 64)      0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, None, 1856)        0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60)                460080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                1830
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 462,069
# Trainable params: 462,069
# Non-trainable params: 0
# _________________________________________________________________

# %%
file_name = "cnn_lstm_weights_store_1.hdf5"    #saves file to create checkpoints for each epoch
checkpoint = ModelCheckpoint(file_name, monitor = 'loss', verbose = 1, save_best_only = True, mode = 'min')
callbacks_list = [checkpoint]

print('Please wait...')

cnn_lstm = model_cnn_lstm.fit(X_train_series_sub, Y_train, validation_data = (X_test_series_sub, Y_test), epochs = epochs, verbose = 1, callbacks = callbacks_list, batch_size = batch)
# Out:
# Please wait...
# W0808 00:57:37.611335 13880 deprecation.py:323] From C:\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0808 00:57:38.982346 13880 deprecation_wrapper.py:119] From C:\Anaconda3\envs\tensorflow\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 12 samples, validate on 7 samples
# Epoch 1/2000
# 12/12 [==============================] - 3s 226ms/step - loss: 2.1830 - val_loss: 1.4359
#
# Epoch 00001: loss improved from inf to 2.18303, saving model to cnn_lstm_weights_store_1.hdf5
# Epoch 2/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4756 - val_loss: 0.7209
#
# Epoch 00002: loss improved from 2.18303 to 1.47561, saving model to cnn_lstm_weights_store_1.hdf5
# Epoch 3/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.9718 - val_loss: 0.1521
#
# Epoch 00003: loss improved from 1.47561 to 0.97181, saving model to cnn_lstm_weights_store_1.hdf5
# Epoch 4/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1541 - val_loss: 0.0319
#
# Epoch 00004: loss improved from 0.97181 to 0.15412, saving model to cnn_lstm_weights_store_1.hdf5
# Epoch 5/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1203 - val_loss: 0.3650
#
# Epoch 00005: loss improved from 0.15412 to 0.12033, saving model to cnn_lstm_weights_store_1.hdf5
# Epoch 6/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5463 - val_loss: 0.3079
#
# Epoch 00006: loss did not improve from 0.12033
# Epoch 7/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6113 - val_loss: 0.0865
#
# Epoch 00007: loss did not improve from 0.12033
# Epoch 8/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2392 - val_loss: 0.0056
#
# Epoch 00008: loss did not improve from 0.12033
# Epoch 9/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1923 - val_loss: 0.0845
#
# Epoch 00009: loss did not improve from 0.12033
# Epoch 10/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0925 - val_loss: 0.2139
#
# Epoch 00010: loss improved from 0.12033 to 0.09253, saving model to cnn_lstm_weights_store_1.hdf5
# Epoch 11/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1966 - val_loss: 0.3036
#
# Epoch 00011: loss did not improve from 0.09253
# Epoch 12/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3105 - val_loss: 0.3286
#
# Epoch 00012: loss did not improve from 0.09253
# Epoch 13/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3264 - val_loss: 0.2973
#
# Epoch 00013: loss did not improve from 0.09253
# Epoch 14/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3016 - val_loss: 0.2310
#
# Epoch 00014: loss did not improve from 0.09253
# Epoch 15/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2710 - val_loss: 0.1463
#
# Epoch 00015: loss did not improve from 0.09253
# Epoch 16/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1341 - val_loss: 0.0698
#
# Epoch 00016: loss did not improve from 0.09253
# Epoch 17/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0494 - val_loss: 0.0191
#
# Epoch 00017: loss improved from 0.09253 to 0.04939, saving model to cnn_lstm_weights_store_1.hdf5
# Epoch 18/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0224 - val_loss: 0.0051
#
# Epoch 00018: loss improved from 0.04939 to 0.02236, saving model to cnn_lstm_weights_store_1.hdf5
# Epoch 19/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0536 - val_loss: 0.0251
#
# Epoch 00019: loss did not improve from 0.02236
# Epoch 20/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1434 - val_loss: 0.0551
#
# Epoch 00020: loss did not improve from 0.02236
# Epoch 21/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1626 - val_loss: 0.0602
#
# Epoch 00021: loss did not improve from 0.02236
# Epoch 22/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1914 - val_loss: 0.0560
#
# Epoch 00022: loss did not improve from 0.02236
# Epoch 23/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1469 - val_loss: 0.0349
#
# Epoch 00023: loss did not improve from 0.02236
# Epoch 24/2000
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0908 - val_loss: 0.0152
#
# Epoch 00024: loss did not improve from 0.02236
# Epoch 25/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1129 - val_loss: 0.0049
#
# Epoch 00025: loss did not improve from 0.02236
# Epoch 26/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0739 - val_loss: 0.0140
#
# Epoch 00026: loss did not improve from 0.02236
# Epoch 27/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0764 - val_loss: 0.0399
#
# Epoch 00027: loss did not improve from 0.02236
# Epoch 28/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0883 - val_loss: 0.0649
#
# Epoch 00028: loss did not improve from 0.02236
# Epoch 29/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1667 - val_loss: 0.0725
#
# Epoch 00029: loss did not improve from 0.02236
# Epoch 30/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1081 - val_loss: 0.0679
#
# Epoch 00030: loss did not improve from 0.02236
# Epoch 31/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0754 - val_loss: 0.0550
#
# Epoch 00031: loss did not improve from 0.02236
# Epoch 32/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1861 - val_loss: 0.0360
#
# Epoch 00032: loss did not improve from 0.02236
# Epoch 33/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1164 - val_loss: 0.0181
#
# Epoch 00033: loss did not improve from 0.02236
# Epoch 34/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0657 - val_loss: 0.0074
#
# Epoch 00034: loss did not improve from 0.02236
# Epoch 35/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0743 - val_loss: 0.0053
#
# Epoch 00035: loss did not improve from 0.02236
# Epoch 36/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0646 - val_loss: 0.0079
#
# Epoch 00036: loss did not improve from 0.02236
# Epoch 37/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0656 - val_loss: 0.0099
#
# Epoch 00037: loss did not improve from 0.02236
# Epoch 38/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0531 - val_loss: 0.0083
#
# Epoch 00038: loss did not improve from 0.02236
# Epoch 39/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0984 - val_loss: 0.0050
#
# Epoch 00039: loss did not improve from 0.02236
# Epoch 40/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0789 - val_loss: 0.0086
#
# Epoch 00040: loss did not improve from 0.02236
# Epoch 41/2000
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0551 - val_loss: 0.0155
#
# Epoch 00041: loss did not improve from 0.02236
# Epoch 42/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0762 - val_loss: 0.0242
#
# Epoch 00042: loss did not improve from 0.02236
# Epoch 43/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0328 - val_loss: 0.0325
#
# Epoch 00043: loss did not improve from 0.02236
# Epoch 44/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1160 - val_loss: 0.0354
#
# Epoch 00044: loss did not improve from 0.02236
# Epoch 45/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0872 - val_loss: 0.0323
#
# Epoch 00045: loss did not improve from 0.02236
# Epoch 46/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0424 - val_loss: 0.0294
#
# Epoch 00046: loss did not improve from 0.02236
# Epoch 47/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0546 - val_loss: 0.0238
#
# Epoch 00047: loss did not improve from 0.02236
# Epoch 48/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0389 - val_loss: 0.0162
#
# Epoch 00048: loss did not improve from 0.02236
# Epoch 49/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0624 - val_loss: 0.0106
#
# Epoch 00049: loss did not improve from 0.02236
# Epoch 50/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0918 - val_loss: 0.0058
#
# Epoch 00050: loss did not improve from 0.02236
# Epoch 51/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0534 - val_loss: 0.0052
#
# Epoch 00051: loss did not improve from 0.02236
# Epoch 52/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0493 - val_loss: 0.0060
#
# Epoch 00052: loss did not improve from 0.02236
# Epoch 53/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0940 - val_loss: 0.0058
#
# Epoch 00053: loss did not improve from 0.02236
# Epoch 54/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0903 - val_loss: 0.0059
#
# Epoch 00054: loss did not improve from 0.02236
# Epoch 55/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0768 - val_loss: 0.0136
#
# Epoch 00055: loss did not improve from 0.02236
# Epoch 56/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0499 - val_loss: 0.0226
#
# Epoch 00056: loss did not improve from 0.02236
# Epoch 57/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0171 - val_loss: 0.0332
#
# Epoch 00057: loss improved from 0.02236 to 0.01710, saving model to cnn_lstm_weights_store_1.hdf5
# Epoch 58/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0559 - val_loss: 0.0371
#
# Epoch 00058: loss did not improve from 0.01710
# Epoch 59/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2709 - val_loss: 0.0240
#
# Epoch 00059: loss did not improve from 0.01710
# Epoch 60/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0841 - val_loss: 0.0135
#
# Epoch 00060: loss did not improve from 0.01710
# Epoch 61/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0980 - val_loss: 0.0059
#
# Epoch 00061: loss did not improve from 0.01710
# Epoch 62/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0360 - val_loss: 0.0051
#
# Epoch 00062: loss did not improve from 0.01710
# Epoch 63/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0560 - val_loss: 0.0049
#
# Epoch 00063: loss did not improve from 0.01710
# Epoch 64/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0972 - val_loss: 0.0074
#
# Epoch 00064: loss did not improve from 0.01710
# Epoch 65/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0443 - val_loss: 0.0155
#
# Epoch 00065: loss did not improve from 0.01710
# Epoch 66/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0265 - val_loss: 0.0320
#
# Epoch 00066: loss did not improve from 0.01710
# Epoch 67/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1303 - val_loss: 0.0319
#
# Epoch 00067: loss did not improve from 0.01710
# Epoch 68/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0307 - val_loss: 0.0289
#
# Epoch 00068: loss did not improve from 0.01710
# Epoch 69/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0732 - val_loss: 0.0192
#
# Epoch 00069: loss did not improve from 0.01710
# Epoch 70/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0638 - val_loss: 0.0093
#
# Epoch 00070: loss did not improve from 0.01710
# Epoch 71/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0488 - val_loss: 0.0048
#
# Epoch 00071: loss did not improve from 0.01710
# Epoch 72/2000
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0299 - val_loss: 0.0110
#
# Epoch 00072: loss did not improve from 0.01710
# Epoch 73/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0868 - val_loss: 0.0149
#
# Epoch 00073: loss did not improve from 0.01710
# Epoch 74/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0714 - val_loss: 0.0062
#
# Epoch 00074: loss did not improve from 0.01710
# Epoch 75/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0435 - val_loss: 0.0091
#
# Epoch 00075: loss did not improve from 0.01710
# Epoch 76/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0402 - val_loss: 0.0302
#
# Epoch 00076: loss did not improve from 0.01710
# Epoch 77/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0958 - val_loss: 0.0516
#
# Epoch 00077: loss did not improve from 0.01710
# Epoch 78/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1634 - val_loss: 0.0538
#
# Epoch 00078: loss did not improve from 0.01710
# Epoch 79/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1332 - val_loss: 0.0387
#
# Epoch 00079: loss did not improve from 0.01710
# Epoch 80/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1083 - val_loss: 0.0159
#
# Epoch 00080: loss did not improve from 0.01710
# Epoch 81/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0479 - val_loss: 0.0066
#
# Epoch 00081: loss did not improve from 0.01710
# Epoch 82/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0517 - val_loss: 0.0060
#
# Epoch 00082: loss did not improve from 0.01710
# Epoch 83/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0180 - val_loss: 0.0055
#
# Epoch 00083: loss did not improve from 0.01710
# Epoch 84/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0630 - val_loss: 0.0061
#
# Epoch 00084: loss did not improve from 0.01710
# Epoch 85/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0481 - val_loss: 0.0097
#
# Epoch 00085: loss did not improve from 0.01710
# Epoch 86/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1145 - val_loss: 0.0131
#
# Epoch 00086: loss did not improve from 0.01710
# Epoch 87/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0370 - val_loss: 0.0174
#
# Epoch 00087: loss did not improve from 0.01710
# Epoch 88/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0297 - val_loss: 0.0175
#
# Epoch 00088: loss did not improve from 0.01710
# Epoch 89/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0579 - val_loss: 0.0154
#
# Epoch 00089: loss did not improve from 0.01710
# Epoch 90/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0774 - val_loss: 0.0109
#
# Epoch 00090: loss did not improve from 0.01710
# Epoch 91/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0419 - val_loss: 0.0058
#
# Epoch 00091: loss did not improve from 0.01710
# Epoch 92/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0459 - val_loss: 0.0050
#
# Epoch 00092: loss did not improve from 0.01710
# Epoch 93/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0650 - val_loss: 0.0056
#
# Epoch 00093: loss did not improve from 0.01710
# Epoch 94/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0829 - val_loss: 0.0116
#
# Epoch 00094: loss did not improve from 0.01710
# Epoch 95/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0360 - val_loss: 0.0210
#
# Epoch 00095: loss did not improve from 0.01710
# Epoch 96/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0238 - val_loss: 0.0394
#
# Epoch 00096: loss did not improve from 0.01710
# Epoch 97/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1920 - val_loss: 0.0374
#
# Epoch 00097: loss did not improve from 0.01710
# Epoch 98/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0554 - val_loss: 0.0285
#
# Epoch 00098: loss did not improve from 0.01710
# Epoch 99/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0560 - val_loss: 0.0188
#
# Epoch 00099: loss did not improve from 0.01710
# Epoch 100/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0436 - val_loss: 0.0059
#
# Epoch 00100: loss did not improve from 0.01710
# Epoch 101/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0482 - val_loss: 0.0068
#
# Epoch 00101: loss did not improve from 0.01710
# Epoch 102/2000
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0508 - val_loss: 0.0079
#
# Epoch 00102: loss did not improve from 0.01710
# Epoch 103/2000
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0766 - val_loss: 0.0060
#
# Epoch 00103: loss did not improve from 0.01710
# Epoch 104/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0576 - val_loss: 0.0113
#
# Epoch 00104: loss did not improve from 0.01710
# Epoch 105/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0339 - val_loss: 0.0271
#
# Epoch 00105: loss did not improve from 0.01710
# Epoch 106/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0518 - val_loss: 0.0447
#
# Epoch 00106: loss did not improve from 0.01710
# Epoch 107/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1264 - val_loss: 0.0448
#
# Epoch 00107: loss did not improve from 0.01710
# Epoch 108/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0724 - val_loss: 0.0293
#
# Epoch 00108: loss did not improve from 0.01710
# Epoch 109/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0268 - val_loss: 0.0129
#
# Epoch 00109: loss did not improve from 0.01710
# Epoch 110/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0246 - val_loss: 0.0054
#
# Epoch 00110: loss did not improve from 0.01710
# Epoch 111/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0882 - val_loss: 0.0052
#
# Epoch 00111: loss did not improve from 0.01710
# Epoch 112/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0338 - val_loss: 0.0097
#
# Epoch 00112: loss did not improve from 0.01710
# Epoch 113/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0333 - val_loss: 0.0172
#
# Epoch 00113: loss did not improve from 0.01710
# Epoch 114/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0228 - val_loss: 0.0259
#
# Epoch 00114: loss did not improve from 0.01710
# Epoch 115/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0464 - val_loss: 0.0299
#
# Epoch 00115: loss did not improve from 0.01710
# Epoch 116/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0884 - val_loss: 0.0273
#
# Epoch 00116: loss did not improve from 0.01710
# Epoch 117/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0195 - val_loss: 0.0271
#
# Epoch 00117: loss did not improve from 0.01710
# Epoch 118/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0372 - val_loss: 0.0256
#
# Epoch 00118: loss did not improve from 0.01710
# Epoch 119/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0517 - val_loss: 0.0193
#
# Epoch 00119: loss did not improve from 0.01710
# Epoch 120/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0766 - val_loss: 0.0076
#
# Epoch 00120: loss did not improve from 0.01710
# Epoch 121/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0541 - val_loss: 0.0047
#
# Epoch 00121: loss did not improve from 0.01710
# Epoch 122/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0256 - val_loss: 0.0065
#
# Epoch 00122: loss did not improve from 0.01710
# Epoch 123/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0587 - val_loss: 0.0080
#
# Epoch 00123: loss did not improve from 0.01710
# Epoch 124/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0519 - val_loss: 0.0067
#
# Epoch 00124: loss did not improve from 0.01710
# Epoch 125/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0571 - val_loss: 0.0047
#
# Epoch 00125: loss did not improve from 0.01710
# Epoch 126/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0294 - val_loss: 0.0096
#
# Epoch 00126: loss did not improve from 0.01710
# Epoch 127/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0190 - val_loss: 0.0248
#
# Epoch 00127: loss did not improve from 0.01710
# Epoch 128/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0448 - val_loss: 0.0404
#
# Epoch 00128: loss did not improve from 0.01710
# Epoch 129/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0458 - val_loss: 0.0468
#
# Epoch 00129: loss did not improve from 0.01710
# Epoch 130/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0476 - val_loss: 0.0452
#
# Epoch 00130: loss did not improve from 0.01710
# Epoch 131/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0595 - val_loss: 0.0352
#
# Epoch 00131: loss did not improve from 0.01710
# Epoch 132/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0872 - val_loss: 0.0133
#
# Epoch 00132: loss did not improve from 0.01710
# Epoch 133/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0607 - val_loss: 0.0048
#
# Epoch 00133: loss did not improve from 0.01710
# Epoch 134/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0271 - val_loss: 0.0058
#
# Epoch 00134: loss did not improve from 0.01710
# Epoch 135/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0509 - val_loss: 0.0048
#
# Epoch 00135: loss did not improve from 0.01710
# Epoch 136/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0688 - val_loss: 0.0170
#
# Epoch 00136: loss did not improve from 0.01710
# Epoch 137/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0308 - val_loss: 0.0349
#
# Epoch 00137: loss did not improve from 0.01710
# Epoch 138/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0644 - val_loss: 0.0391
#
# Epoch 00138: loss did not improve from 0.01710
# Epoch 139/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0325 - val_loss: 0.0324
#
# Epoch 00139: loss did not improve from 0.01710
# Epoch 140/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0485 - val_loss: 0.0217
#
# Epoch 00140: loss did not improve from 0.01710
# Epoch 141/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0467 - val_loss: 0.0102
#
# Epoch 00141: loss did not improve from 0.01710
# Epoch 142/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0358 - val_loss: 0.0055
#
# Epoch 00142: loss did not improve from 0.01710
# Epoch 143/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0168 - val_loss: 0.0048
#
# Epoch 00143: loss improved from 0.01710 to 0.01681, saving model to cnn_lstm_weights_store_1.hdf5
# Epoch 144/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0296 - val_loss: 0.0045
#
# Epoch 00144: loss did not improve from 0.01681
# Epoch 145/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1047 - val_loss: 0.0047
#
# Epoch 00145: loss did not improve from 0.01681
# Epoch 146/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0379 - val_loss: 0.0078
#
# Epoch 00146: loss did not improve from 0.01681
# Epoch 147/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0406 - val_loss: 0.0123
#
# Epoch 00147: loss did not improve from 0.01681
# Epoch 148/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0297 - val_loss: 0.0212
#
# Epoch 00148: loss did not improve from 0.01681
# Epoch 149/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0308 - val_loss: 0.0288
#
# Epoch 00149: loss did not improve from 0.01681
# Epoch 150/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0219 - val_loss: 0.0327
#
# Epoch 00150: loss did not improve from 0.01681
# Epoch 151/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0193 - val_loss: 0.0308
#
# Epoch 00151: loss did not improve from 0.01681
# Epoch 152/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0869 - val_loss: 0.0198
#
# Epoch 00152: loss did not improve from 0.01681
# Epoch 153/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0567 - val_loss: 0.0087
#
# Epoch 00153: loss did not improve from 0.01681
# Epoch 154/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0548 - val_loss: 0.0053
#
# Epoch 00154: loss did not improve from 0.01681
# Epoch 155/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0369 - val_loss: 0.0068
#
# Epoch 00155: loss did not improve from 0.01681
# Epoch 156/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0563 - val_loss: 0.0133
#
# Epoch 00156: loss did not improve from 0.01681
# Epoch 157/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0147 - val_loss: 0.0248
#
# Epoch 00157: loss improved from 0.01681 to 0.01467, saving model to cnn_lstm_weights_store_1.hdf5
# Epoch 158/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0363 - val_loss: 0.0335
#
# Epoch 00158: loss did not improve from 0.01467
# Epoch 159/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.0462
#
# Epoch 00159: loss improved from 0.01467 to 0.00772, saving model to cnn_lstm_weights_store_1.hdf5
# Epoch 160/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0843 - val_loss: 0.0428
#
# Epoch 00160: loss did not improve from 0.00772
# Epoch 161/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0159 - val_loss: 0.0404
#
# Epoch 00161: loss did not improve from 0.00772
# Epoch 162/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0520 - val_loss: 0.0315
#
# Epoch 00162: loss did not improve from 0.00772
# Epoch 163/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0305 - val_loss: 0.0230
#
# Epoch 00163: loss did not improve from 0.00772
# Epoch 164/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0250 - val_loss: 0.0217
#
# Epoch 00164: loss did not improve from 0.00772
# Epoch 165/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0102 - val_loss: 0.0250
#
# Epoch 00165: loss did not improve from 0.00772
# Epoch 166/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0797 - val_loss: 0.0293
#
# Epoch 00166: loss did not improve from 0.00772
# Epoch 167/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0503 - val_loss: 0.0285
#
# Epoch 00167: loss did not improve from 0.00772
# Epoch 168/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0931 - val_loss: 0.0209
#
# Epoch 00168: loss did not improve from 0.00772
# Epoch 169/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0348 - val_loss: 0.0162
#
# Epoch 00169: loss did not improve from 0.00772
# Epoch 170/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0516 - val_loss: 0.0090
#
# Epoch 00170: loss did not improve from 0.00772
# Epoch 171/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0350 - val_loss: 0.0051
#
# Epoch 00171: loss did not improve from 0.00772
# Epoch 172/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0309 - val_loss: 0.0048
#
# Epoch 00172: loss did not improve from 0.00772
# Epoch 173/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0814 - val_loss: 0.0048
#
# Epoch 00173: loss did not improve from 0.00772
# Epoch 174/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0491 - val_loss: 0.0089
#
# Epoch 00174: loss did not improve from 0.00772
# Epoch 175/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1251 - val_loss: 0.0120
#
# Epoch 00175: loss did not improve from 0.00772
# Epoch 176/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0312 - val_loss: 0.0147
#
# Epoch 00176: loss did not improve from 0.00772
# Epoch 177/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0105 - val_loss: 0.0148
#
# Epoch 00177: loss did not improve from 0.00772
# Epoch 178/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0710 - val_loss: 0.0097
#
# Epoch 00178: loss did not improve from 0.00772
# Epoch 179/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0314 - val_loss: 0.0083
#
# Epoch 00179: loss did not improve from 0.00772
# Epoch 180/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0217 - val_loss: 0.0081
#
# Epoch 00180: loss did not improve from 0.00772
# Epoch 181/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.0150
#
# Epoch 00181: loss did not improve from 0.00772
# Epoch 182/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0402 - val_loss: 0.0261
#
# Epoch 00182: loss did not improve from 0.00772
# Epoch 183/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0488 - val_loss: 0.0244
#
# Epoch 00183: loss did not improve from 0.00772
# Epoch 184/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0184 - val_loss: 0.0197
#
# Epoch 00184: loss did not improve from 0.00772
# Epoch 185/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0798 - val_loss: 0.0200
#
# Epoch 00185: loss did not improve from 0.00772
# Epoch 186/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0291 - val_loss: 0.0279
#
# Epoch 00186: loss did not improve from 0.00772
# Epoch 187/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0189 - val_loss: 0.0321
#
# Epoch 00187: loss did not improve from 0.00772
# Epoch 188/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0219 - val_loss: 0.0338
#
# Epoch 00188: loss did not improve from 0.00772
# Epoch 189/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0743 - val_loss: 0.0202
#
# Epoch 00189: loss did not improve from 0.00772
# Epoch 190/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0405 - val_loss: 0.0071
#
# Epoch 00190: loss did not improve from 0.00772
# Epoch 191/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0370 - val_loss: 0.0047
#
# Epoch 00191: loss did not improve from 0.00772
# Epoch 192/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0425 - val_loss: 0.0047
#
# Epoch 00192: loss did not improve from 0.00772
# Epoch 193/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0309 - val_loss: 0.0045
#
# Epoch 00193: loss did not improve from 0.00772
# Epoch 194/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0453 - val_loss: 0.0075
#
# Epoch 00194: loss did not improve from 0.00772
# Epoch 195/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0512 - val_loss: 0.0285
#
# Epoch 00195: loss did not improve from 0.00772
# Epoch 196/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0447 - val_loss: 0.0437
#
# Epoch 00196: loss did not improve from 0.00772
# Epoch 197/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0249 - val_loss: 0.0525
#
# Epoch 00197: loss did not improve from 0.00772
# Epoch 198/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0569 - val_loss: 0.0468
#
# Epoch 00198: loss did not improve from 0.00772
# Epoch 199/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0609 - val_loss: 0.0312
#
# Epoch 00199: loss did not improve from 0.00772
# Epoch 200/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0409 - val_loss: 0.0146
#
# Epoch 00200: loss did not improve from 0.00772
# Epoch 201/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0407 - val_loss: 0.0050
#
# Epoch 00201: loss did not improve from 0.00772
# Epoch 202/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0876 - val_loss: 0.0047
#
# Epoch 00202: loss did not improve from 0.00772
# Epoch 203/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0462 - val_loss: 0.0049
#
# Epoch 00203: loss did not improve from 0.00772
# Epoch 204/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1256 - val_loss: 0.0045
#
# Epoch 00204: loss did not improve from 0.00772
# Epoch 205/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0409 - val_loss: 0.0110
#
# Epoch 00205: loss did not improve from 0.00772
# Epoch 206/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0940 - val_loss: 0.0299
#
# Epoch 00206: loss did not improve from 0.00772
# Epoch 207/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0337 - val_loss: 0.0451
#
# Epoch 00207: loss did not improve from 0.00772
# Epoch 208/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0436 - val_loss: 0.0521
#
# Epoch 00208: loss did not improve from 0.00772
# Epoch 209/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0775 - val_loss: 0.0440
#
# Epoch 00209: loss did not improve from 0.00772
# Epoch 210/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0313 - val_loss: 0.0300
#
# Epoch 00210: loss did not improve from 0.00772
# Epoch 211/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0357 - val_loss: 0.0136
#
# Epoch 00211: loss did not improve from 0.00772
# Epoch 212/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0207 - val_loss: 0.0051
#
# Epoch 00212: loss did not improve from 0.00772
# Epoch 213/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0388 - val_loss: 0.0062
#
# Epoch 00213: loss did not improve from 0.00772
# Epoch 214/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0861 - val_loss: 0.0054
#
# Epoch 00214: loss did not improve from 0.00772
# Epoch 215/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0548 - val_loss: 0.0071
#
# Epoch 00215: loss did not improve from 0.00772
# Epoch 216/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0510 - val_loss: 0.0266
#
# Epoch 00216: loss did not improve from 0.00772
# Epoch 217/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0293 - val_loss: 0.0346
#
# Epoch 00217: loss did not improve from 0.00772
# Epoch 218/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0285 - val_loss: 0.0340
#
# Epoch 00218: loss did not improve from 0.00772
# Epoch 219/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1018 - val_loss: 0.0215
#
# Epoch 00219: loss did not improve from 0.00772
# Epoch 220/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0450 - val_loss: 0.0110
#
# Epoch 00220: loss did not improve from 0.00772
# Epoch 221/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0162 - val_loss: 0.0070
#
# Epoch 00221: loss did not improve from 0.00772
# Epoch 222/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0572 - val_loss: 0.0074
#
# Epoch 00222: loss did not improve from 0.00772
# Epoch 223/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0501 - val_loss: 0.0066
#
# Epoch 00223: loss did not improve from 0.00772
# Epoch 224/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0401 - val_loss: 0.0083
#
# Epoch 00224: loss did not improve from 0.00772
# Epoch 225/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0280 - val_loss: 0.0098
#
# Epoch 00225: loss did not improve from 0.00772
# Epoch 226/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0459 - val_loss: 0.0078
#
# Epoch 00226: loss did not improve from 0.00772
# Epoch 227/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0337 - val_loss: 0.0132
#
# Epoch 00227: loss did not improve from 0.00772
# Epoch 228/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0182 - val_loss: 0.0206
#
# Epoch 00228: loss did not improve from 0.00772
# Epoch 229/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0284 - val_loss: 0.0303
#
# Epoch 00229: loss did not improve from 0.00772
# Epoch 230/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0589 - val_loss: 0.0293
#
# Epoch 00230: loss did not improve from 0.00772
# Epoch 231/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0700 - val_loss: 0.0182
#
# Epoch 00231: loss did not improve from 0.00772
# Epoch 232/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0655 - val_loss: 0.0059
#
# Epoch 00232: loss did not improve from 0.00772
# Epoch 233/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0578 - val_loss: 0.0058
#
# Epoch 00233: loss did not improve from 0.00772
# Epoch 234/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0457 - val_loss: 0.0058
#
# Epoch 00234: loss did not improve from 0.00772
# Epoch 235/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1116 - val_loss: 0.0053
#
# Epoch 00235: loss did not improve from 0.00772
# Epoch 236/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0445 - val_loss: 0.0185
#
# Epoch 00236: loss did not improve from 0.00772
# Epoch 237/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0287 - val_loss: 0.0365
#
# Epoch 00237: loss did not improve from 0.00772
# Epoch 238/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0617 - val_loss: 0.0437
#
# Epoch 00238: loss did not improve from 0.00772
# Epoch 239/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0398 - val_loss: 0.0377
#
# Epoch 00239: loss did not improve from 0.00772
# Epoch 240/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0263 - val_loss: 0.0299
#
# Epoch 00240: loss did not improve from 0.00772
# Epoch 241/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0212 - val_loss: 0.0205
#
# Epoch 00241: loss did not improve from 0.00772
# Epoch 242/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0093 - val_loss: 0.0157
#
# Epoch 00242: loss did not improve from 0.00772
# Epoch 243/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0245 - val_loss: 0.0107
#
# Epoch 00243: loss did not improve from 0.00772
# Epoch 244/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0153 - val_loss: 0.0078
#
# Epoch 00244: loss did not improve from 0.00772
# Epoch 245/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0263 - val_loss: 0.0066
#
# Epoch 00245: loss did not improve from 0.00772
# Epoch 246/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0382 - val_loss: 0.0061
#
# Epoch 00246: loss did not improve from 0.00772
# Epoch 247/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0421 - val_loss: 0.0108
#
# Epoch 00247: loss did not improve from 0.00772
# Epoch 248/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0243 - val_loss: 0.0193
#
# Epoch 00248: loss did not improve from 0.00772
# Epoch 249/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0410 - val_loss: 0.0329
#
# Epoch 00249: loss did not improve from 0.00772
# Epoch 250/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0804 - val_loss: 0.0340
#
# Epoch 00250: loss did not improve from 0.00772
# Epoch 251/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0430 - val_loss: 0.0278
#
# Epoch 00251: loss did not improve from 0.00772
# Epoch 252/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1237 - val_loss: 0.0117
#
# Epoch 00252: loss did not improve from 0.00772
# Epoch 253/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0701 - val_loss: 0.0047
#
# Epoch 00253: loss did not improve from 0.00772
# Epoch 254/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0207 - val_loss: 0.0165
#
# Epoch 00254: loss did not improve from 0.00772
# Epoch 255/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0855 - val_loss: 0.0281
#
# Epoch 00255: loss did not improve from 0.00772
# Epoch 256/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1451 - val_loss: 0.0058
#
# Epoch 00256: loss did not improve from 0.00772
# Epoch 257/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0415 - val_loss: 0.0137
#
# Epoch 00257: loss did not improve from 0.00772
# Epoch 258/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0693 - val_loss: 0.0386
#
# Epoch 00258: loss did not improve from 0.00772
# Epoch 259/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0201 - val_loss: 0.0496
#
# Epoch 00259: loss did not improve from 0.00772
# Epoch 260/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0129 - val_loss: 0.0499
#
# Epoch 00260: loss did not improve from 0.00772
# Epoch 261/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0384 - val_loss: 0.0403
#
# Epoch 00261: loss did not improve from 0.00772
# Epoch 262/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0750 - val_loss: 0.0202
#
# Epoch 00262: loss did not improve from 0.00772
# Epoch 263/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0616 - val_loss: 0.0069
#
# Epoch 00263: loss did not improve from 0.00772
# Epoch 264/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0438 - val_loss: 0.0047
#
# Epoch 00264: loss did not improve from 0.00772
# Epoch 265/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0376 - val_loss: 0.0043
#
# Epoch 00265: loss did not improve from 0.00772
# Epoch 266/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0607 - val_loss: 0.0042
#
# Epoch 00266: loss did not improve from 0.00772
# Epoch 267/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0620 - val_loss: 0.0042
#
# Epoch 00267: loss did not improve from 0.00772
# Epoch 268/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0654 - val_loss: 0.0064
#
# Epoch 00268: loss did not improve from 0.00772
# Epoch 269/2000
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0544 - val_loss: 0.0202
#
# Epoch 00269: loss did not improve from 0.00772
# Epoch 270/2000
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0476 - val_loss: 0.0341
#
# Epoch 00270: loss did not improve from 0.00772
# Epoch 271/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1325 - val_loss: 0.0273
#
# Epoch 00271: loss did not improve from 0.00772
# Epoch 272/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0844 - val_loss: 0.0128
#
# Epoch 00272: loss did not improve from 0.00772
# Epoch 273/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0292 - val_loss: 0.0054
#
# Epoch 00273: loss did not improve from 0.00772
# Epoch 274/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0409 - val_loss: 0.0042
#
# Epoch 00274: loss did not improve from 0.00772
# Epoch 275/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0508 - val_loss: 0.0045
#
# Epoch 00275: loss did not improve from 0.00772
# Epoch 276/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0486 - val_loss: 0.0053
#
# Epoch 00276: loss did not improve from 0.00772
# Epoch 277/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0246 - val_loss: 0.0067
#
# Epoch 00277: loss did not improve from 0.00772
# Epoch 278/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0491 - val_loss: 0.0096
#
# Epoch 00278: loss did not improve from 0.00772
# Epoch 279/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0197 - val_loss: 0.0148
#
# Epoch 00279: loss did not improve from 0.00772
# Epoch 280/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0560 - val_loss: 0.0137
#
# Epoch 00280: loss did not improve from 0.00772
# Epoch 281/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0199 - val_loss: 0.0129
#
# Epoch 00281: loss did not improve from 0.00772
# Epoch 282/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0516 - val_loss: 0.0119
#
# Epoch 00282: loss did not improve from 0.00772
# Epoch 283/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0258 - val_loss: 0.0114
#
# Epoch 00283: loss did not improve from 0.00772
# Epoch 284/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0128 - val_loss: 0.0102
#
# Epoch 00284: loss did not improve from 0.00772
# Epoch 285/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0232 - val_loss: 0.0095
#
# Epoch 00285: loss did not improve from 0.00772
# Epoch 286/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0349 - val_loss: 0.0116
#
# Epoch 00286: loss did not improve from 0.00772
# Epoch 287/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0408 - val_loss: 0.0150
#
# Epoch 00287: loss did not improve from 0.00772
# Epoch 288/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0219 - val_loss: 0.0222
#
# Epoch 00288: loss did not improve from 0.00772
# Epoch 289/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0275 - val_loss: 0.0314
#
# Epoch 00289: loss did not improve from 0.00772
# Epoch 290/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0326 - val_loss: 0.0294
#
# Epoch 00290: loss did not improve from 0.00772
# Epoch 291/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0389 - val_loss: 0.0255
#
# Epoch 00291: loss did not improve from 0.00772
# Epoch 292/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0165 - val_loss: 0.0235
#
# Epoch 00292: loss did not improve from 0.00772
# Epoch 293/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0459 - val_loss: 0.0167
#
# Epoch 00293: loss did not improve from 0.00772
# Epoch 294/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0296 - val_loss: 0.0139
#
# Epoch 00294: loss did not improve from 0.00772
# Epoch 295/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0363 - val_loss: 0.0114
#
# Epoch 00295: loss did not improve from 0.00772
# Epoch 296/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0289 - val_loss: 0.0119
#
# Epoch 00296: loss did not improve from 0.00772
# Epoch 297/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0231 - val_loss: 0.0088
#
# Epoch 00297: loss did not improve from 0.00772
# Epoch 298/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0557 - val_loss: 0.0078
#
# Epoch 00298: loss did not improve from 0.00772
# Epoch 299/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0755 - val_loss: 0.0092
#
# Epoch 00299: loss did not improve from 0.00772
# Epoch 300/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0437 - val_loss: 0.0114
#
# Epoch 00300: loss did not improve from 0.00772
# Epoch 301/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0215 - val_loss: 0.0155
#
# Epoch 00301: loss did not improve from 0.00772
# Epoch 302/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0434 - val_loss: 0.0237
#
# Epoch 00302: loss did not improve from 0.00772
# Epoch 303/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0971 - val_loss: 0.0180
#
# Epoch 00303: loss did not improve from 0.00772
# Epoch 304/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0314 - val_loss: 0.0112
#
# Epoch 00304: loss did not improve from 0.00772
# Epoch 305/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0558 - val_loss: 0.0085
#
# Epoch 00305: loss did not improve from 0.00772
# Epoch 306/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0384 - val_loss: 0.0106
#
# Epoch 00306: loss did not improve from 0.00772
# Epoch 307/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0262 - val_loss: 0.0120
#
# Epoch 00307: loss did not improve from 0.00772
# Epoch 308/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0112 - val_loss: 0.0184
#
# Epoch 00308: loss did not improve from 0.00772
# Epoch 309/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0576 - val_loss: 0.0196
#
# Epoch 00309: loss did not improve from 0.00772
# Epoch 310/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0311 - val_loss: 0.0173
#
# Epoch 00310: loss did not improve from 0.00772
# Epoch 311/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0304 - val_loss: 0.0174
#
# Epoch 00311: loss did not improve from 0.00772
# Epoch 312/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0399 - val_loss: 0.0118
#
# Epoch 00312: loss did not improve from 0.00772
# Epoch 313/2000
# ...
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0217 - val_loss: 0.0118
#
# Epoch 01895: loss did not improve from 0.00269
# Epoch 1896/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0296 - val_loss: 0.0078
#
# Epoch 01896: loss did not improve from 0.00269
# Epoch 1897/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.0053
#
# Epoch 01897: loss did not improve from 0.00269
# Epoch 1898/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0278 - val_loss: 0.0040
#
# Epoch 01898: loss did not improve from 0.00269
# Epoch 1899/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0262 - val_loss: 0.0042
#
# Epoch 01899: loss did not improve from 0.00269
# Epoch 1900/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0263 - val_loss: 0.0050
#
# Epoch 01900: loss did not improve from 0.00269
# Epoch 1901/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0141 - val_loss: 0.0073
#
# Epoch 01901: loss did not improve from 0.00269
# Epoch 1902/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0194 - val_loss: 0.0088
#
# Epoch 01902: loss did not improve from 0.00269
# Epoch 1903/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0158 - val_loss: 0.0089
#
# Epoch 01903: loss did not improve from 0.00269
# Epoch 1904/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0076 - val_loss: 0.0104
#
# Epoch 01904: loss did not improve from 0.00269
# Epoch 1905/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0193 - val_loss: 0.0110
#
# Epoch 01905: loss did not improve from 0.00269
# Epoch 1906/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0191 - val_loss: 0.0090
#
# Epoch 01906: loss did not improve from 0.00269
# Epoch 1907/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0063 - val_loss: 0.0070
#
# Epoch 01907: loss did not improve from 0.00269
# Epoch 1908/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0129 - val_loss: 0.0059
#
# Epoch 01908: loss did not improve from 0.00269
# Epoch 1909/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0071
#
# Epoch 01909: loss did not improve from 0.00269
# Epoch 1910/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0194 - val_loss: 0.0074
#
# Epoch 01910: loss did not improve from 0.00269
# Epoch 1911/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0188 - val_loss: 0.0081
#
# Epoch 01911: loss did not improve from 0.00269
# Epoch 1912/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0091
#
# Epoch 01912: loss did not improve from 0.00269
# Epoch 1913/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0137 - val_loss: 0.0095
#
# Epoch 01913: loss did not improve from 0.00269
# Epoch 1914/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0044 - val_loss: 0.0090
#
# Epoch 01914: loss did not improve from 0.00269
# Epoch 1915/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0108 - val_loss: 0.0094
#
# Epoch 01915: loss did not improve from 0.00269
# Epoch 1916/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0162 - val_loss: 0.0087
#
# Epoch 01916: loss did not improve from 0.00269
# Epoch 1917/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0156 - val_loss: 0.0064
#
# Epoch 01917: loss did not improve from 0.00269
# Epoch 1918/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0085 - val_loss: 0.0037
#
# Epoch 01918: loss did not improve from 0.00269
# Epoch 1919/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0280 - val_loss: 0.0036
#
# Epoch 01919: loss did not improve from 0.00269
# Epoch 1920/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0125 - val_loss: 0.0040
#
# Epoch 01920: loss did not improve from 0.00269
# Epoch 1921/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0248 - val_loss: 0.0065
#
# Epoch 01921: loss did not improve from 0.00269
# Epoch 1922/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0106 - val_loss: 0.0118
#
# Epoch 01922: loss did not improve from 0.00269
# Epoch 1923/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0199 - val_loss: 0.0153
#
# Epoch 01923: loss did not improve from 0.00269
# Epoch 1924/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0163 - val_loss: 0.0153
#
# Epoch 01924: loss did not improve from 0.00269
# Epoch 1925/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0345 - val_loss: 0.0124
#
# Epoch 01925: loss did not improve from 0.00269
# Epoch 1926/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.0105
#
# Epoch 01926: loss did not improve from 0.00269
# Epoch 1927/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0251 - val_loss: 0.0055
#
# Epoch 01927: loss did not improve from 0.00269
# Epoch 1928/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0248 - val_loss: 0.0037
#
# Epoch 01928: loss did not improve from 0.00269
# Epoch 1929/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0203 - val_loss: 0.0030
#
# Epoch 01929: loss did not improve from 0.00269
# Epoch 1930/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0183 - val_loss: 0.0031
#
# Epoch 01930: loss did not improve from 0.00269
# Epoch 1931/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0211 - val_loss: 0.0046
#
# Epoch 01931: loss did not improve from 0.00269
# Epoch 1932/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0221 - val_loss: 0.0068
#
# Epoch 01932: loss did not improve from 0.00269
# Epoch 1933/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0144 - val_loss: 0.0099
#
# Epoch 01933: loss did not improve from 0.00269
# Epoch 1934/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0174 - val_loss: 0.0124
#
# Epoch 01934: loss did not improve from 0.00269
# Epoch 1935/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0127 - val_loss: 0.0125
#
# Epoch 01935: loss did not improve from 0.00269
# Epoch 1936/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - val_loss: 0.0111
#
# Epoch 01936: loss did not improve from 0.00269
# Epoch 1937/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0214 - val_loss: 0.0080
#
# Epoch 01937: loss did not improve from 0.00269
# Epoch 1938/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0059
#
# Epoch 01938: loss did not improve from 0.00269
# Epoch 1939/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0040
#
# Epoch 01939: loss did not improve from 0.00269
# Epoch 1940/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0196 - val_loss: 0.0036
#
# Epoch 01940: loss did not improve from 0.00269
# Epoch 1941/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0038
#
# Epoch 01941: loss did not improve from 0.00269
# Epoch 1942/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0043
#
# Epoch 01942: loss did not improve from 0.00269
# Epoch 1943/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0129 - val_loss: 0.0037
#
# Epoch 01943: loss did not improve from 0.00269
# Epoch 1944/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0245 - val_loss: 0.0038
#
# Epoch 01944: loss did not improve from 0.00269
# Epoch 1945/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0156 - val_loss: 0.0045
#
# Epoch 01945: loss did not improve from 0.00269
# Epoch 1946/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0224 - val_loss: 0.0040
#
# Epoch 01946: loss did not improve from 0.00269
# Epoch 1947/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0179 - val_loss: 0.0041
#
# Epoch 01947: loss did not improve from 0.00269
# Epoch 1948/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0167 - val_loss: 0.0051
#
# Epoch 01948: loss did not improve from 0.00269
# Epoch 1949/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0134 - val_loss: 0.0061
#
# Epoch 01949: loss did not improve from 0.00269
# Epoch 1950/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0226 - val_loss: 0.0066
#
# Epoch 01950: loss did not improve from 0.00269
# Epoch 1951/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0070
#
# Epoch 01951: loss did not improve from 0.00269
# Epoch 1952/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0092
#
# Epoch 01952: loss did not improve from 0.00269
# Epoch 1953/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0252 - val_loss: 0.0102
#
# Epoch 01953: loss did not improve from 0.00269
# Epoch 1954/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.0113
#
# Epoch 01954: loss did not improve from 0.00269
# Epoch 1955/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0103
#
# Epoch 01955: loss did not improve from 0.00269
# Epoch 1956/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0148 - val_loss: 0.0077
#
# Epoch 01956: loss did not improve from 0.00269
# Epoch 1957/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0186 - val_loss: 0.0071
#
# Epoch 01957: loss did not improve from 0.00269
# Epoch 1958/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0244 - val_loss: 0.0072
#
# Epoch 01958: loss did not improve from 0.00269
# Epoch 1959/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0181 - val_loss: 0.0070
#
# Epoch 01959: loss did not improve from 0.00269
# Epoch 1960/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0074
#
# Epoch 01960: loss did not improve from 0.00269
# Epoch 1961/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0277 - val_loss: 0.0068
#
# Epoch 01961: loss did not improve from 0.00269
# Epoch 1962/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0075 - val_loss: 0.0072
#
# Epoch 01962: loss did not improve from 0.00269
# Epoch 1963/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.0087
#
# Epoch 01963: loss did not improve from 0.00269
# Epoch 1964/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0238 - val_loss: 0.0082
#
# Epoch 01964: loss did not improve from 0.00269
# Epoch 1965/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0131 - val_loss: 0.0082
#
# Epoch 01965: loss did not improve from 0.00269
# Epoch 1966/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0130 - val_loss: 0.0087
#
# Epoch 01966: loss did not improve from 0.00269
# Epoch 1967/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0234 - val_loss: 0.0075
#
# Epoch 01967: loss did not improve from 0.00269
# Epoch 1968/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0146 - val_loss: 0.0069
#
# Epoch 01968: loss did not improve from 0.00269
# Epoch 1969/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0230 - val_loss: 0.0069
#
# Epoch 01969: loss did not improve from 0.00269
# Epoch 1970/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0170 - val_loss: 0.0072
#
# Epoch 01970: loss did not improve from 0.00269
# Epoch 1971/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0147 - val_loss: 0.0082
#
# Epoch 01971: loss did not improve from 0.00269
# Epoch 1972/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0105
#
# Epoch 01972: loss did not improve from 0.00269
# Epoch 1973/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0378 - val_loss: 0.0122
#
# Epoch 01973: loss did not improve from 0.00269
# Epoch 1974/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0150 - val_loss: 0.0113
#
# Epoch 01974: loss did not improve from 0.00269
# Epoch 1975/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0193 - val_loss: 0.0091
#
# Epoch 01975: loss did not improve from 0.00269
# Epoch 1976/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0130 - val_loss: 0.0087
#
# Epoch 01976: loss did not improve from 0.00269
# Epoch 1977/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0130 - val_loss: 0.0084
#
# Epoch 01977: loss did not improve from 0.00269
# Epoch 1978/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0186 - val_loss: 0.0066
#
# Epoch 01978: loss did not improve from 0.00269
# Epoch 1979/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0168 - val_loss: 0.0074
#
# Epoch 01979: loss did not improve from 0.00269
# Epoch 1980/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0160 - val_loss: 0.0079
#
# Epoch 01980: loss did not improve from 0.00269
# Epoch 1981/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0110 - val_loss: 0.0077
#
# Epoch 01981: loss did not improve from 0.00269
# Epoch 1982/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0163 - val_loss: 0.0066
#
# Epoch 01982: loss did not improve from 0.00269
# Epoch 1983/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0065
#
# Epoch 01983: loss did not improve from 0.00269
# Epoch 1984/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0152 - val_loss: 0.0057
#
# Epoch 01984: loss did not improve from 0.00269
# Epoch 1985/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0050
#
# Epoch 01985: loss did not improve from 0.00269
# Epoch 1986/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0127 - val_loss: 0.0047
#
# Epoch 01986: loss did not improve from 0.00269
# Epoch 1987/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0131 - val_loss: 0.0049
#
# Epoch 01987: loss did not improve from 0.00269
# Epoch 1988/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0268 - val_loss: 0.0055
#
# Epoch 01988: loss did not improve from 0.00269
# Epoch 1989/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0077
#
# Epoch 01989: loss did not improve from 0.00269
# Epoch 1990/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0099 - val_loss: 0.0106
#
# Epoch 01990: loss did not improve from 0.00269
# Epoch 1991/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0124
#
# Epoch 01991: loss did not improve from 0.00269
# Epoch 1992/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0228 - val_loss: 0.0116
#
# Epoch 01992: loss did not improve from 0.00269
# Epoch 1993/2000
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0162 - val_loss: 0.0097
#
# Epoch 01993: loss did not improve from 0.00269
# Epoch 1994/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0094 - val_loss: 0.0086
#
# Epoch 01994: loss did not improve from 0.00269
# Epoch 1995/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0070 - val_loss: 0.0081
#
# Epoch 01995: loss did not improve from 0.00269
# Epoch 1996/2000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0279 - val_loss: 0.0077
#
# Epoch 01996: loss did not improve from 0.00269
# Epoch 1997/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.0082
#
# Epoch 01997: loss did not improve from 0.00269
# Epoch 1998/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.0077
#
# Epoch 01998: loss did not improve from 0.00269
# Epoch 1999/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0160 - val_loss: 0.0072
#
# Epoch 01999: loss did not improve from 0.00269
# Epoch 2000/2000
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0172 - val_loss: 0.0054
#
# Epoch 02000: loss did not improve from 0.00269

# %%
#load from saved file
file_name = "cnn_lstm_weights_store_1.hdf5"

model_cnn_lstm.load_weights(file_name)
model_cnn_lstm.compile(loss = 'mse', optimizer = 'adam')

#prediction
cnn_lstm_train_prediction = model_cnn_lstm.predict(X_train_series_sub)
cnn_lstm_test_prediction = model_cnn_lstm.predict(X_test_series_sub)

cnn_lstm_train_prediction
# Out:
# array([[1.4278002],
#        [1.4880353],
#        [1.5069249],
#        [1.4157519],
#        [1.4028581],
#        [1.478154 ],
#        [1.4242017],
#        [1.5142789],
#        [1.4765154],
#        [1.4063959],
#        [1.4478455],
#        [1.4140166]], dtype=float32)

# %%
print('Train Error (RMSE):', np.sqrt(mean_squared_error(Y_train, cnn_lstm_train_prediction)))
print('Test Error (RMSE):', np.sqrt(mean_squared_error(Y_test, cnn_lstm_test_prediction)))
# Out:
# Train Error (RMSE): 0.10162008847270289
# Test Error (RMSE): 0.11135429285840663

# %%
#save to csv
date_format = "%Y-%m-%d"
a = datetime.strptime(train['Date'].max(), date_format)
a = a + timedelta(7)

next_date = str(datetime.date(a))
next_sales = np.round(cnn_lstm_train_prediction[len(cnn_lstm_train_prediction) - 1], 2)

dataset = dataset.append(pd.DataFrame({'Store' : '1',
                                       'Item' : '1',
                                       'Date' : next_date,
                                       'Weekly_Sales' : next_sales}))
dataset.tail()

# %%
dataset.to_csv('sales data-set.csv', index = False)
