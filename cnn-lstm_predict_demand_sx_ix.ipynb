# %%
import numpy as np
from tensorflow import set_random_seed
from numpy.random import seed
import pandas as pd
#import matplotlib.pyplot as plt
from keras import optimizers
from keras.callbacks import ModelCheckpoint
from keras.utils import plot_model
from keras.models import Sequential, Model
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers import Dense, LSTM, RepeatVector, TimeDistributed, Flatten, Dropout
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from datetime import datetime
from datetime import timedelta
# Out:
# Using TensorFlow backend.

# %%
#dataset_empty = 0
set_random_seed(1)
seed(1)

# %%
#Convert the train data into time series
def time_series_data(data, window, lag):
    dropnan = True
    cols, names = list(), list()

    for i in range(window, 0, -1):
        #past time series data (t-)
        cols.append(data.shift(i))
        names = names + [('%s(t-%d)' % (col, i)) for col in data.columns]
    
    #current time series data (t = 0)
    cols.append(data)
    names = names + [('%s(t)' % (col)) for col in data.columns]
    
    #future data (t + lag)
    cols.append(data.shift(-lag))
    names = names + [('%s(t+%d)' % (col, lag)) for col in data.columns]
    
    #all data
    all_data = pd.concat(cols, axis=1)
    all_data.columns = names
    
    #drops rows with NaN
    if dropnan:
        all_data.dropna(inplace=True)
    return all_data

# %%
dataset = pd.read_csv('interest_over_time_s1_1_3.csv', usecols = ['Store', 'Item', 'Date', 'Weekly_Demand'])
train = dataset[['Store', 'Item', 'Date', 'Weekly_Demand']]
train = train.loc[(train['Store'] == 1) & (train['Item'] == 1)]
#train = train[(train['Date'] >= '2012-01-01')]
#train = train.loc[train['Store'] == 3]

print(train.head())
# Out:
#    Store  Item        Date  Weekly_Demand
# 0      1     1  2010-02-07             99
# 1      1     1  2010-02-14             54
# 2      1     1  2010-02-21            100
# 3      1     1  2010-02-28              0
# 4      1     1  2010-03-07             51

# %%
#Re-arranges the train dataset to apply shift methods
train_r = train.sort_values('Date').groupby(['Item', 'Store', 'Date'], as_index=False)
train_r = train_r.agg({'Weekly_Demand':['mean']})
train_r.columns = ['Item', 'Store', 'Date', 'Weekly_Demand']
#cols_to_drop = ['Date']
#train_r.drop(cols_to_drop, axis=1, inplace=True)
train_r.head()
# Out:
#    Item  Store        Date  Weekly_Demand
# 0     1      1  2010-02-07             99
# 1     1      1  2010-02-14             54
# 2     1      1  2010-02-21            100
# 3     1      1  2010-02-28              0
# 4     1      1  2010-03-07             51

# %%
#weekly demand in 0-10 scale
train_r['Weekly_Demand'] = train_r['Weekly_Demand'] / 10
train_r.head()
# Out:
#    Item  Store        Date  Weekly_Demand
# 0     1      1  2010-02-07            9.9
# 1     1      1  2010-02-14            5.4
# 2     1      1  2010-02-21           10.0
# 3     1      1  2010-02-28            0.0
# 4     1      1  2010-03-07            5.1

# %%
#the model will use last 117 weekly demand data and 
#current timestep (7 days) to forecast next weekly demand data 12 weeks ahead

window = 117
lag = 12

series_data = time_series_data(train_r, window, lag)
series_data.head()
# Out:
#      Item(t-117)  Store(t-117) Date(t-117)  Weekly_Demand(t-117)  Item(t-116)  \
# 117          1.0           1.0  2010-02-07                   9.9          1.0
# 118          1.0           1.0  2010-02-14                   5.4          1.0
# 119          1.0           1.0  2010-02-21                  10.0          1.0
# 120          1.0           1.0  2010-02-28                   0.0          1.0
# 121          1.0           1.0  2010-03-07                   5.1          1.0
#
#      Store(t-116) Date(t-116)  Weekly_Demand(t-116)  Item(t-115)  \
# 117           1.0  2010-02-14                   5.4          1.0
# 118           1.0  2010-02-21                  10.0          1.0
# 119           1.0  2010-02-28                   0.0          1.0
# 120           1.0  2010-03-07                   5.1          1.0
# 121           1.0  2010-03-14                   0.0          1.0
#
#      Store(t-115)  ...   Date(t-1)  Weekly_Demand(t-1)  Item(t)  Store(t)  \
# 117           1.0  ...  2012-04-29                 2.1        1         1
# 118           1.0  ...  2012-05-06                 2.1        1         1
# 119           1.0  ...  2012-05-13                 0.0        1         1
# 120           1.0  ...  2012-05-20                 3.2        1         1
# 121           1.0  ...  2012-05-27                 2.1        1         1
#
#         Date(t)  Weekly_Demand(t)  Item(t+12)  Store(t+12)  Date(t+12)  \
# 117  2012-05-06               2.1         1.0          1.0  2012-07-29
# 118  2012-05-13               0.0         1.0          1.0  2012-08-05
# 119  2012-05-20               3.2         1.0          1.0  2012-08-12
# 120  2012-05-27               2.1         1.0          1.0  2012-08-19
# 121  2012-06-03               2.1         1.0          1.0  2012-08-26
#
#      Weekly_Demand(t+12)
# 117                  2.9
# 118                  3.3
# 119                  2.1
# 120                  2.0
# 121                  2.9
#
# [5 rows x 476 columns]

# %%
future_dates = series_data[['Date(t+%d)' % lag]]
future_dates
# Out:
#      Date(t+12)
# 117  2012-07-29
# 118  2012-08-05
# 119  2012-08-12
# 120  2012-08-19
# 121  2012-08-26
# 122  2012-09-02
# 123  2012-09-09
# 124  2012-09-16
# 125  2012-09-23
# 126  2012-09-30
# 127  2012-10-07
# 128  2012-10-14
# 129  2012-10-21
# 130  2012-10-28

# %%
#drops last record of (t + lag)
last_record_item = 'Item(t-%d)' % window
last_record_store = 'Store(t-%d)' % window
series_data = series_data[(series_data['Item(t)'] == series_data[last_record_item])]
series_data = series_data[(series_data['Store(t)'] == series_data[last_record_store])]

#drops Item and Store columns
cols_to_drop = [('%s(t+%d)' % (col, lag)) for col in ['Item', 'Store', 'Date']]
for i in range(window, 0, -1):
    cols_to_drop += [('%s(t-%d)' % (col, i)) for col in ['Item', 'Store', 'Date']]

series_data.drop(cols_to_drop, axis=1, inplace=True)
series_data.drop(['Item(t)', 'Store(t)', 'Date(t)'], axis=1, inplace=True)

lbls_col = 'Weekly_Demand(t+%d)' % lag
lbls = series_data[lbls_col]
series_data = series_data.drop(lbls_col, axis=1)

series_data.head()
# Out:
#      Weekly_Demand(t-117)  Weekly_Demand(t-116)  Weekly_Demand(t-115)  \
# 117                   9.9                   5.4                  10.0
# 118                   5.4                  10.0                   0.0
# 119                  10.0                   0.0                   5.1
# 120                   0.0                   5.1                   0.0
# 121                   5.1                   0.0                   5.0
#
#      Weekly_Demand(t-114)  Weekly_Demand(t-113)  Weekly_Demand(t-112)  \
# 117                   0.0                   5.1                   0.0
# 118                   5.1                   0.0                   5.0
# 119                   0.0                   5.0                   5.6
# 120                   5.0                   5.6                   5.2
# 121                   5.6                   5.2                   4.9
#
#      Weekly_Demand(t-111)  Weekly_Demand(t-110)  Weekly_Demand(t-109)  \
# 117                   5.0                   5.6                   5.2
# 118                   5.6                   5.2                   4.9
# 119                   5.2                   4.9                   5.1
# 120                   4.9                   5.1                   0.0
# 121                   5.1                   0.0                   0.0
#
#      Weekly_Demand(t-108)  ...  Weekly_Demand(t-9)  Weekly_Demand(t-8)  \
# 117                   4.9  ...                 3.0                 3.9
# 118                   5.1  ...                 3.9                 2.6
# 119                   0.0  ...                 2.6                 2.1
# 120                   0.0  ...                 2.1                 3.1
# 121                   5.5  ...                 3.1                 2.1
#
#      Weekly_Demand(t-7)  Weekly_Demand(t-6)  Weekly_Demand(t-5)  \
# 117                 2.6                 2.1                 3.1
# 118                 2.1                 3.1                 2.1
# 119                 3.1                 2.1                 3.9
# 120                 2.1                 3.9                 5.0
# 121                 3.9                 5.0                 2.1
#
#      Weekly_Demand(t-4)  Weekly_Demand(t-3)  Weekly_Demand(t-2)  \
# 117                 2.1                 3.9                 5.0
# 118                 3.9                 5.0                 2.1
# 119                 5.0                 2.1                 2.1
# 120                 2.1                 2.1                 0.0
# 121                 2.1                 0.0                 3.2
#
#      Weekly_Demand(t-1)  Weekly_Demand(t)
# 117                 2.1               2.1
# 118                 2.1               0.0
# 119                 0.0               3.2
# 120                 3.2               2.1
# 121                 2.1               2.1
#
# [5 rows x 118 columns]

# %%
series_data.shape[0]
# Out:
# 14

# %%
#train and test split

X_train_1, X_test_1, Y_train_1, Y_test_1 = train_test_split(series_data, lbls.values, test_size=0.1, random_state=0)
X_train = X_train_1
Y_train = Y_train_1

X_train_1, X_test_1, Y_train_1, Y_test_1 = train_test_split(series_data, lbls.values, test_size=0.7, random_state=0)
X_test = X_test_1
Y_test = Y_test_1

print('Train dataset:', X_train.shape)
print('Test dataset:', X_test.shape)
X_train.head()
# Out:
# Train dataset: (12, 118)
# Test dataset: (10, 118)
#      Weekly_Demand(t-117)  Weekly_Demand(t-116)  Weekly_Demand(t-115)  \
# 121                   5.1                   0.0                   5.0
# 128                   0.0                   0.0                   5.5
# 119                  10.0                   0.0                   5.1
# 130                   5.5                   5.5                   5.5
# 126                   4.9                   5.1                   0.0
#
#      Weekly_Demand(t-114)  Weekly_Demand(t-113)  Weekly_Demand(t-112)  \
# 121                   5.6                   5.2                   4.9
# 128                   5.5                   5.5                   5.2
# 119                   0.0                   5.0                   5.6
# 130                   5.2                   0.0                   0.0
# 126                   0.0                   5.5                   5.5
#
#      Weekly_Demand(t-111)  Weekly_Demand(t-110)  Weekly_Demand(t-109)  \
# 121                   5.1                   0.0                   0.0
# 128                   0.0                   0.0                   5.4
# 119                   5.2                   4.9                   5.1
# 130                   5.4                   0.0                   5.4
# 126                   5.5                   5.2                   0.0
#
#      Weekly_Demand(t-108)  ...  Weekly_Demand(t-9)  Weekly_Demand(t-8)  \
# 121                   5.5  ...                 3.1                 2.1
# 128                   0.0  ...                 3.2                 2.1
# 119                   0.0  ...                 2.6                 2.1
# 130                   5.3  ...                 2.1                 2.9
# 126                   0.0  ...                 2.1                 0.0
#
#      Weekly_Demand(t-7)  Weekly_Demand(t-6)  Weekly_Demand(t-5)  \
# 121                 3.9                 5.0                 2.1
# 128                 2.1                 2.9                 1.9
# 119                 3.1                 2.1                 3.9
# 130                 1.9                 3.1                 2.2
# 126                 3.2                 2.1                 2.1
#
#      Weekly_Demand(t-4)  Weekly_Demand(t-3)  Weekly_Demand(t-2)  \
# 121                 2.1                 0.0                 3.2
# 128                 3.1                 2.2                 2.2
# 119                 5.0                 2.1                 2.1
# 130                 2.2                 2.9                 4.1
# 126                 2.9                 1.9                 3.1
#
#      Weekly_Demand(t-1)  Weekly_Demand(t)
# 121                 2.1               2.1
# 128                 2.9               4.1
# 119                 0.0               3.2
# 130                 2.9               3.3
# 126                 2.2               2.2
#
# [5 rows x 118 columns]

# %%
X_train_series = X_train.values.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_series = X_test.values.reshape((X_test.shape[0], X_test.shape[1], 1))
print('Train dataset:', X_train_series.shape)
print('Test dataset:', X_test_series.shape)
# Out:
# Train dataset: (12, 118, 1)
# Test dataset: (10, 118, 1)

# %%
#CNN-LSTM
subsequences = 2
time_steps = X_train_series.shape[1] // subsequences
X_train_series_sub = X_train_series.reshape((X_train_series.shape[0], subsequences, time_steps, 1))
X_test_series_sub = X_test_series.reshape((X_test_series.shape[0], subsequences, time_steps, 1))
print('Train dataset:', X_train_series_sub.shape)
print('Test dataset:', X_test_series_sub.shape)
# Out:
# Train dataset: (12, 2, 59, 1)
# Test dataset: (10, 2, 59, 1)

# %%
epochs = 5000
batch = 32
learning_rate = 0.00000001
adam = optimizers.Adam(learning_rate)

# %%
model_cnn_lstm = Sequential()
model_cnn_lstm.add(TimeDistributed(Conv1D(filters = 64, kernel_size = 1, activation = 'relu'), input_shape = (None, X_train_series_sub.shape[2], X_train_series_sub.shape[3])))
model_cnn_lstm.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model_cnn_lstm.add(TimeDistributed(Flatten()))
model_cnn_lstm.add(LSTM(60, activation = 'relu'))
model_cnn_lstm.add(Dropout(0.5))
model_cnn_lstm.add(Dense(30, activation = 'relu'))
model_cnn_lstm.add(Dropout(0.5))
model_cnn_lstm.add(Dense(1))
model_cnn_lstm.compile(loss = 'mse', optimizer = 'adam')
model_cnn_lstm.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_4 (TimeDist (None, None, 59, 64)      128
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, None, 29, 64)      0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, None, 1856)        0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60)                460080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                1830
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 462,069
# Trainable params: 462,069
# Non-trainable params: 0
# _________________________________________________________________

# %%
file_name = "cnn_lstm_gtrends_weights_s1_i1.hdf5"    #saves file to create checkpoints for each epoch
checkpoint = ModelCheckpoint(file_name, monitor = 'loss', verbose = 1, save_best_only = True, mode = 'min')
callbacks_list = [checkpoint]

print('Please wait...')

cnn_lstm = model_cnn_lstm.fit(X_train_series_sub, Y_train, validation_data = (X_test_series_sub, Y_test), epochs = epochs, verbose = 1, callbacks = callbacks_list, batch_size = batch)
# Out:
# W0809 23:26:25.356479  9920 deprecation.py:323] From C:\Anaconda3\envs\tf-cpu\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Please wait...
# W0809 23:26:25.754416  9920 deprecation_wrapper.py:119] From C:\Anaconda3\envs\tf-cpu\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 12 samples, validate on 10 samples
# Epoch 1/5000
# 12/12 [==============================] - 1s 68ms/step - loss: 7.2249 - val_loss: 1.2816
#
# Epoch 00001: loss improved from inf to 7.22494, saving model to cnn_lstm_gtrends_weights_s1_i1.hdf5
# Epoch 2/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7446 - val_loss: 2.4224
#
# Epoch 00002: loss improved from 7.22494 to 4.74457, saving model to cnn_lstm_gtrends_weights_s1_i1.hdf5
# Epoch 3/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.0167 - val_loss: 1.4581
#
# Epoch 00003: loss improved from 4.74457 to 3.01675, saving model to cnn_lstm_gtrends_weights_s1_i1.hdf5
# Epoch 4/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 6.8570 - val_loss: 1.2631
#
# Epoch 00004: loss did not improve from 3.01675
# Epoch 5/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 6.4673 - val_loss: 1.3132
#
# Epoch 00005: loss did not improve from 3.01675
# Epoch 6/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4423 - val_loss: 1.7460
#
# Epoch 00006: loss improved from 3.01675 to 1.44233, saving model to cnn_lstm_gtrends_weights_s1_i1.hdf5
# Epoch 7/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.7719 - val_loss: 1.8856
#
# Epoch 00007: loss did not improve from 1.44233
# Epoch 8/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.3333 - val_loss: 1.5446
#
# Epoch 00008: loss did not improve from 1.44233
# Epoch 9/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 5.9854 - val_loss: 1.7481
#
# Epoch 00009: loss did not improve from 1.44233
# Epoch 10/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3336 - val_loss: 1.9401
#
# Epoch 00010: loss did not improve from 1.44233
# Epoch 11/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.1862 - val_loss: 2.5688
#
# Epoch 00011: loss did not improve from 1.44233
# Epoch 12/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.4326 - val_loss: 3.2059
#
# Epoch 00012: loss did not improve from 1.44233
# Epoch 13/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.1640 - val_loss: 3.5488
#
# Epoch 00013: loss did not improve from 1.44233
# Epoch 14/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.3140 - val_loss: 3.4851
#
# Epoch 00014: loss did not improve from 1.44233
# Epoch 15/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5379 - val_loss: 3.0379
#
# Epoch 00015: loss did not improve from 1.44233
# Epoch 16/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.9546 - val_loss: 2.3925
#
# Epoch 00016: loss did not improve from 1.44233
# Epoch 17/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7240 - val_loss: 1.8040
#
# Epoch 00017: loss did not improve from 1.44233
# Epoch 18/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.4726 - val_loss: 1.6678
#
# Epoch 00018: loss did not improve from 1.44233
# Epoch 19/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.9451 - val_loss: 1.6131
#
# Epoch 00019: loss did not improve from 1.44233
# Epoch 20/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.0429 - val_loss: 1.5855
#
# Epoch 00020: loss did not improve from 1.44233
# Epoch 21/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 3.1358 - val_loss: 1.5235
#
# Epoch 00021: loss did not improve from 1.44233
# Epoch 22/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.3737 - val_loss: 1.3255
#
# Epoch 00022: loss did not improve from 1.44233
# Epoch 23/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 5.1401 - val_loss: 1.6754
#
# Epoch 00023: loss did not improve from 1.44233
# Epoch 24/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.7688 - val_loss: 2.0523
#
# Epoch 00024: loss did not improve from 1.44233
# Epoch 25/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.5211 - val_loss: 2.3058
#
# Epoch 00025: loss did not improve from 1.44233
# Epoch 26/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7272 - val_loss: 2.2537
#
# Epoch 00026: loss did not improve from 1.44233
# Epoch 27/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2188 - val_loss: 2.0981
#
# Epoch 00027: loss did not improve from 1.44233
# Epoch 28/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.5655 - val_loss: 1.7916
#
# Epoch 00028: loss did not improve from 1.44233
# Epoch 29/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.9676 - val_loss: 1.4485
#
# Epoch 00029: loss did not improve from 1.44233
# Epoch 30/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5781 - val_loss: 1.3322
#
# Epoch 00030: loss did not improve from 1.44233
# Epoch 31/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.7926 - val_loss: 1.2718
#
# Epoch 00031: loss did not improve from 1.44233
# Epoch 32/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.7593 - val_loss: 1.3162
#
# Epoch 00032: loss did not improve from 1.44233
# Epoch 33/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9618 - val_loss: 1.4576
#
# Epoch 00033: loss improved from 1.44233 to 0.96181, saving model to cnn_lstm_gtrends_weights_s1_i1.hdf5
# Epoch 34/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.7955 - val_loss: 1.5702
#
# Epoch 00034: loss did not improve from 0.96181
# Epoch 35/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8110 - val_loss: 1.7708
#
# Epoch 00035: loss did not improve from 0.96181
# Epoch 36/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.4092 - val_loss: 1.8885
#
# Epoch 00036: loss did not improve from 0.96181
# Epoch 37/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.1328 - val_loss: 2.1730
#
# Epoch 00037: loss did not improve from 0.96181
# Epoch 38/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6682 - val_loss: 2.3031
#
# Epoch 00038: loss did not improve from 0.96181
# Epoch 39/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0965 - val_loss: 2.2113
#
# Epoch 00039: loss did not improve from 0.96181
# Epoch 40/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.6163 - val_loss: 2.2981
#
# Epoch 00040: loss did not improve from 0.96181
# Epoch 41/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3255 - val_loss: 2.3065
#
# Epoch 00041: loss did not improve from 0.96181
# Epoch 42/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6112 - val_loss: 2.1247
#
# Epoch 00042: loss did not improve from 0.96181
# Epoch 43/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9539 - val_loss: 1.7857
#
# Epoch 00043: loss did not improve from 0.96181
# Epoch 44/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2174 - val_loss: 1.3352
#
# Epoch 00044: loss did not improve from 0.96181
# Epoch 45/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.3260 - val_loss: 1.1291
#
# Epoch 00045: loss did not improve from 0.96181
# Epoch 46/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9782 - val_loss: 1.1746
#
# Epoch 00046: loss did not improve from 0.96181
# Epoch 47/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.4217 - val_loss: 1.8487
#
# Epoch 00047: loss did not improve from 0.96181
# Epoch 48/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9059 - val_loss: 2.5184
#
# Epoch 00048: loss did not improve from 0.96181
# Epoch 49/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.2214 - val_loss: 2.8418
#
# Epoch 00049: loss did not improve from 0.96181
# Epoch 50/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6966 - val_loss: 2.8705
#
# Epoch 00050: loss did not improve from 0.96181
# Epoch 51/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.4480 - val_loss: 2.7023
#
# Epoch 00051: loss did not improve from 0.96181
# Epoch 52/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.4180 - val_loss: 2.3784
#
# Epoch 00052: loss did not improve from 0.96181
# Epoch 53/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0839 - val_loss: 1.9594
#
# Epoch 00053: loss did not improve from 0.96181
# Epoch 54/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6569 - val_loss: 1.5584
#
# Epoch 00054: loss did not improve from 0.96181
# Epoch 55/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.5852 - val_loss: 1.1992
#
# Epoch 00055: loss did not improve from 0.96181
# Epoch 56/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.2974 - val_loss: 0.9376
#
# Epoch 00056: loss did not improve from 0.96181
# Epoch 57/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9608 - val_loss: 0.9007
#
# Epoch 00057: loss did not improve from 0.96181
# Epoch 58/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1596 - val_loss: 1.0397
#
# Epoch 00058: loss did not improve from 0.96181
# Epoch 59/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8168 - val_loss: 0.9840
#
# Epoch 00059: loss did not improve from 0.96181
# Epoch 60/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 5.9464 - val_loss: 1.0517
#
# Epoch 00060: loss did not improve from 0.96181
# Epoch 61/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.2449 - val_loss: 1.7276
#
# Epoch 00061: loss did not improve from 0.96181
# Epoch 62/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7277 - val_loss: 2.5066
#
# Epoch 00062: loss did not improve from 0.96181
# Epoch 63/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.9943 - val_loss: 2.9687
#
# Epoch 00063: loss did not improve from 0.96181
# Epoch 64/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6629 - val_loss: 3.2194
#
# Epoch 00064: loss did not improve from 0.96181
# Epoch 65/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.1678 - val_loss: 3.3232
#
# Epoch 00065: loss did not improve from 0.96181
# Epoch 66/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.2568 - val_loss: 3.3179
#
# Epoch 00066: loss did not improve from 0.96181
# Epoch 67/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7609 - val_loss: 3.1960
#
# Epoch 00067: loss did not improve from 0.96181
# Epoch 68/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.5909 - val_loss: 2.9955
#
# Epoch 00068: loss did not improve from 0.96181
# Epoch 69/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.4946 - val_loss: 2.7756
#
# Epoch 00069: loss did not improve from 0.96181
# Epoch 70/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.9886 - val_loss: 2.4545
#
# Epoch 00070: loss did not improve from 0.96181
# Epoch 71/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.3276 - val_loss: 2.3024
#
# Epoch 00071: loss did not improve from 0.96181
# Epoch 72/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.4720 - val_loss: 2.1338
#
# Epoch 00072: loss did not improve from 0.96181
# Epoch 73/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8654 - val_loss: 1.9158
#
# Epoch 00073: loss improved from 0.96181 to 0.86544, saving model to cnn_lstm_gtrends_weights_s1_i1.hdf5
# Epoch 74/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1177 - val_loss: 1.6812
#
# Epoch 00074: loss did not improve from 0.86544
# Epoch 75/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6751 - val_loss: 1.7496
#
# Epoch 00075: loss did not improve from 0.86544
# Epoch 76/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7303 - val_loss: 1.7729
#
# Epoch 00076: loss did not improve from 0.86544
# Epoch 77/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8180 - val_loss: 1.7091
#
# Epoch 00077: loss did not improve from 0.86544
# Epoch 78/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7065 - val_loss: 1.5557
#
# Epoch 00078: loss did not improve from 0.86544
# Epoch 79/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.0569 - val_loss: 1.5165
#
# Epoch 00079: loss did not improve from 0.86544
# Epoch 80/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7156 - val_loss: 1.5290
#
# Epoch 00080: loss did not improve from 0.86544
# Epoch 81/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9518 - val_loss: 1.4870
#
# Epoch 00081: loss did not improve from 0.86544
# Epoch 82/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6863 - val_loss: 1.4071
#
# Epoch 00082: loss did not improve from 0.86544
# Epoch 83/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.3502 - val_loss: 1.4334
#
# Epoch 00083: loss did not improve from 0.86544
# Epoch 84/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4672 - val_loss: 1.6118
#
# Epoch 00084: loss did not improve from 0.86544
# Epoch 85/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1203 - val_loss: 1.7837
#
# Epoch 00085: loss did not improve from 0.86544
# Epoch 86/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0478 - val_loss: 1.9057
#
# Epoch 00086: loss did not improve from 0.86544
# Epoch 87/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.0186 - val_loss: 1.9283
#
# Epoch 00087: loss did not improve from 0.86544
# Epoch 88/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8077 - val_loss: 1.8837
#
# Epoch 00088: loss did not improve from 0.86544
# Epoch 89/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.8359 - val_loss: 1.8363
#
# Epoch 00089: loss did not improve from 0.86544
# Epoch 90/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8502 - val_loss: 1.7737
#
# Epoch 00090: loss did not improve from 0.86544
# Epoch 91/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7591 - val_loss: 1.6458
#
# Epoch 00091: loss did not improve from 0.86544
# Epoch 92/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6363 - val_loss: 1.4727
#
# Epoch 00092: loss did not improve from 0.86544
# Epoch 93/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7472 - val_loss: 1.3911
#
# Epoch 00093: loss did not improve from 0.86544
# Epoch 94/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0216 - val_loss: 1.4494
#
# Epoch 00094: loss did not improve from 0.86544
# Epoch 95/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7010 - val_loss: 1.6936
#
# Epoch 00095: loss did not improve from 0.86544
# Epoch 96/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0334 - val_loss: 1.9227
#
# Epoch 00096: loss did not improve from 0.86544
# Epoch 97/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6280 - val_loss: 2.0943
#
# Epoch 00097: loss did not improve from 0.86544
# Epoch 98/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.7198 - val_loss: 2.1632
#
# Epoch 00098: loss did not improve from 0.86544
# Epoch 99/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6921 - val_loss: 2.3146
#
# Epoch 00099: loss did not improve from 0.86544
# Epoch 100/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6069 - val_loss: 2.5294
#
# Epoch 00100: loss did not improve from 0.86544
# Epoch 101/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.3248 - val_loss: 2.6088
#
# Epoch 00101: loss did not improve from 0.86544
# Epoch 102/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2203 - val_loss: 2.5691
#
# Epoch 00102: loss did not improve from 0.86544
# Epoch 103/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.2171 - val_loss: 2.3251
#
# Epoch 00103: loss did not improve from 0.86544
# Epoch 104/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1385 - val_loss: 2.0321
#
# Epoch 00104: loss did not improve from 0.86544
# Epoch 105/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.3473 - val_loss: 1.7519
#
# Epoch 00105: loss did not improve from 0.86544
# Epoch 106/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4672 - val_loss: 1.6127
#
# Epoch 00106: loss did not improve from 0.86544
# Epoch 107/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9047 - val_loss: 1.4195
#
# Epoch 00107: loss did not improve from 0.86544
# Epoch 108/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.5340 - val_loss: 1.2184
#
# Epoch 00108: loss did not improve from 0.86544
# Epoch 109/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7963 - val_loss: 1.0865
#
# Epoch 00109: loss improved from 0.86544 to 0.79634, saving model to cnn_lstm_gtrends_weights_s1_i1.hdf5
# Epoch 110/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9737 - val_loss: 1.1247
#
# Epoch 00110: loss did not improve from 0.79634
# Epoch 111/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.1888 - val_loss: 1.2427
#
# Epoch 00111: loss did not improve from 0.79634
# Epoch 112/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7997 - val_loss: 1.7798
#
# Epoch 00112: loss did not improve from 0.79634
# Epoch 113/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1985 - val_loss: 2.4362
#
# Epoch 00113: loss did not improve from 0.79634
# Epoch 114/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0952 - val_loss: 2.8450
#
# Epoch 00114: loss did not improve from 0.79634
# Epoch 115/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8318 - val_loss: 2.9841
#
# Epoch 00115: loss did not improve from 0.79634
# Epoch 116/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7829 - val_loss: 2.9759
#
# Epoch 00116: loss did not improve from 0.79634
# Epoch 117/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5106 - val_loss: 2.8335
#
# Epoch 00117: loss did not improve from 0.79634
# Epoch 118/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6128 - val_loss: 2.5894
#
# Epoch 00118: loss did not improve from 0.79634
# Epoch 119/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.5054 - val_loss: 2.2961
#
# Epoch 00119: loss did not improve from 0.79634
# Epoch 120/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2770 - val_loss: 1.9966
#
# Epoch 00120: loss did not improve from 0.79634
# Epoch 121/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.3378 - val_loss: 1.6960
#
# Epoch 00121: loss did not improve from 0.79634
# Epoch 122/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5391 - val_loss: 1.4173
#
# Epoch 00122: loss did not improve from 0.79634
# Epoch 123/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0527 - val_loss: 1.2066
#
# Epoch 00123: loss did not improve from 0.79634
# Epoch 124/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.3598 - val_loss: 1.1150
#
# Epoch 00124: loss did not improve from 0.79634
# Epoch 125/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7592 - val_loss: 1.0346
#
# Epoch 00125: loss did not improve from 0.79634
# Epoch 126/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8115 - val_loss: 0.9769
#
# Epoch 00126: loss did not improve from 0.79634
# Epoch 127/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.3314 - val_loss: 0.9654
#
# Epoch 00127: loss did not improve from 0.79634
# Epoch 128/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8744 - val_loss: 0.9666
#
# Epoch 00128: loss did not improve from 0.79634
# Epoch 129/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3544 - val_loss: 0.9697
#
# Epoch 00129: loss did not improve from 0.79634
# Epoch 130/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4643 - val_loss: 1.0061
#
# Epoch 00130: loss did not improve from 0.79634
# Epoch 131/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 6.5820 - val_loss: 1.5086
#
# Epoch 00131: loss did not improve from 0.79634
# Epoch 132/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3106 - val_loss: 2.1139
#
# Epoch 00132: loss did not improve from 0.79634
# Epoch 133/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2732 - val_loss: 2.6371
#
# Epoch 00133: loss did not improve from 0.79634
# Epoch 134/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0570 - val_loss: 2.9171
#
# Epoch 00134: loss did not improve from 0.79634
# Epoch 135/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5008 - val_loss: 2.8739
#
# Epoch 00135: loss did not improve from 0.79634
# Epoch 136/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6727 - val_loss: 2.6920
#
# Epoch 00136: loss did not improve from 0.79634
# Epoch 137/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7831 - val_loss: 2.3333
#
# Epoch 00137: loss did not improve from 0.79634
# Epoch 138/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4697 - val_loss: 1.9659
#
# Epoch 00138: loss did not improve from 0.79634
# Epoch 139/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.6685 - val_loss: 1.6365
#
# Epoch 00139: loss did not improve from 0.79634
# Epoch 140/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.5071 - val_loss: 1.3822
#
# Epoch 00140: loss did not improve from 0.79634
# Epoch 141/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8511 - val_loss: 1.3988
#
# Epoch 00141: loss did not improve from 0.79634
# Epoch 142/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.4008 - val_loss: 1.6914
#
# Epoch 00142: loss did not improve from 0.79634
# Epoch 143/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.8518 - val_loss: 1.9807
#
# Epoch 00143: loss did not improve from 0.79634
# Epoch 144/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3419 - val_loss: 2.2180
#
# Epoch 00144: loss did not improve from 0.79634
# Epoch 145/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9145 - val_loss: 2.4112
#
# Epoch 00145: loss did not improve from 0.79634
# Epoch 146/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.8752 - val_loss: 2.6542
#
# Epoch 00146: loss did not improve from 0.79634
# Epoch 147/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.5807 - val_loss: 2.7395
#
# Epoch 00147: loss did not improve from 0.79634
# Epoch 148/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3417 - val_loss: 2.7148
#
# Epoch 00148: loss did not improve from 0.79634
# Epoch 149/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5149 - val_loss: 2.6291
#
# Epoch 00149: loss did not improve from 0.79634
# Epoch 150/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5551 - val_loss: 2.6146
#
# Epoch 00150: loss did not improve from 0.79634
# Epoch 151/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2909 - val_loss: 2.5781
#
# Epoch 00151: loss did not improve from 0.79634
# Epoch 152/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1442 - val_loss: 2.5279
#
# Epoch 00152: loss did not improve from 0.79634
# Epoch 153/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6150 - val_loss: 2.4642
#
# Epoch 00153: loss did not improve from 0.79634
# Epoch 154/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.2493 - val_loss: 2.3729
#
# Epoch 00154: loss did not improve from 0.79634
# Epoch 155/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8830 - val_loss: 2.3089
#
# Epoch 00155: loss did not improve from 0.79634
# Epoch 156/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.9449 - val_loss: 2.2230
#
# Epoch 00156: loss did not improve from 0.79634
# Epoch 157/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7244 - val_loss: 2.1267
#
# Epoch 00157: loss did not improve from 0.79634
# Epoch 158/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.5377 - val_loss: 2.0538
#
# Epoch 00158: loss did not improve from 0.79634
# Epoch 159/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7864 - val_loss: 1.9879
#
# Epoch 00159: loss did not improve from 0.79634
# Epoch 160/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.0564 - val_loss: 1.8956
#
# Epoch 00160: loss did not improve from 0.79634
# Epoch 161/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8105 - val_loss: 1.8558
#
# Epoch 00161: loss did not improve from 0.79634
# Epoch 162/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7742 - val_loss: 1.8193
#
# Epoch 00162: loss did not improve from 0.79634
# Epoch 163/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8059 - val_loss: 1.8586
#
# Epoch 00163: loss did not improve from 0.79634
# Epoch 164/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2350 - val_loss: 1.8731
#
# Epoch 00164: loss did not improve from 0.79634
# Epoch 165/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1479 - val_loss: 1.8201
#
# Epoch 00165: loss did not improve from 0.79634
# Epoch 166/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5966 - val_loss: 1.7959
#
# Epoch 00166: loss did not improve from 0.79634
# Epoch 167/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.4267 - val_loss: 1.7331
#
# Epoch 00167: loss did not improve from 0.79634
# Epoch 168/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8337 - val_loss: 1.6816
#
# Epoch 00168: loss did not improve from 0.79634
# Epoch 169/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2877 - val_loss: 1.6354
#
# Epoch 00169: loss did not improve from 0.79634
# Epoch 170/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9190 - val_loss: 1.5723
#
# Epoch 00170: loss did not improve from 0.79634
# Epoch 171/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8099 - val_loss: 1.5582
#
# Epoch 00171: loss did not improve from 0.79634
# Epoch 172/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1913 - val_loss: 1.5443
#
# Epoch 00172: loss did not improve from 0.79634
# Epoch 173/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7252 - val_loss: 1.6428
#
# Epoch 00173: loss did not improve from 0.79634
# Epoch 174/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.5141 - val_loss: 1.6953
#
# Epoch 00174: loss did not improve from 0.79634
# Epoch 175/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2385 - val_loss: 1.6605
#
# Epoch 00175: loss did not improve from 0.79634
# Epoch 176/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9510 - val_loss: 1.6572
#
# Epoch 00176: loss did not improve from 0.79634
# Epoch 177/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1923 - val_loss: 1.7340
#
# Epoch 00177: loss did not improve from 0.79634
# Epoch 178/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3649 - val_loss: 1.8016
#
# Epoch 00178: loss did not improve from 0.79634
# Epoch 179/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6851 - val_loss: 1.8429
#
# Epoch 00179: loss did not improve from 0.79634
# Epoch 180/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3040 - val_loss: 1.8285
#
# Epoch 00180: loss did not improve from 0.79634
# Epoch 181/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6037 - val_loss: 1.8570
#
# Epoch 00181: loss did not improve from 0.79634
# Epoch 182/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5529 - val_loss: 1.8249
#
# Epoch 00182: loss did not improve from 0.79634
# Epoch 183/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4930 - val_loss: 1.7377
#
# Epoch 00183: loss did not improve from 0.79634
# Epoch 184/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4193 - val_loss: 1.6775
#
# Epoch 00184: loss did not improve from 0.79634
# Epoch 185/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 4.3820 - val_loss: 1.8931
#
# Epoch 00185: loss did not improve from 0.79634
# Epoch 186/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2425 - val_loss: 2.0935
#
# Epoch 00186: loss did not improve from 0.79634
# Epoch 187/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9561 - val_loss: 2.1966
#
# Epoch 00187: loss did not improve from 0.79634
# Epoch 188/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.9099 - val_loss: 2.2216
#
# Epoch 00188: loss did not improve from 0.79634
# Epoch 189/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2761 - val_loss: 2.2020
#
# Epoch 00189: loss did not improve from 0.79634
# Epoch 190/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2508 - val_loss: 2.1292
#
# Epoch 00190: loss did not improve from 0.79634
# Epoch 191/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8420 - val_loss: 2.0340
#
# Epoch 00191: loss did not improve from 0.79634
# Epoch 192/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9663 - val_loss: 1.9477
#
# Epoch 00192: loss did not improve from 0.79634
# Epoch 193/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7946 - val_loss: 1.8262
#
# Epoch 00193: loss did not improve from 0.79634
# Epoch 194/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6795 - val_loss: 1.7052
#
# Epoch 00194: loss did not improve from 0.79634
# Epoch 195/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9991 - val_loss: 1.6331
#
# Epoch 00195: loss did not improve from 0.79634
# Epoch 196/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7464 - val_loss: 1.5422
#
# Epoch 00196: loss did not improve from 0.79634
# Epoch 197/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6106 - val_loss: 1.4287
#
# Epoch 00197: loss did not improve from 0.79634
# Epoch 198/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6188 - val_loss: 1.3993
#
# Epoch 00198: loss did not improve from 0.79634
# Epoch 199/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8868 - val_loss: 1.3833
#
# Epoch 00199: loss did not improve from 0.79634
# Epoch 200/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 3.1917 - val_loss: 1.3534
#
# Epoch 00200: loss did not improve from 0.79634
# Epoch 201/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5634 - val_loss: 1.3024
#
# Epoch 00201: loss improved from 0.79634 to 0.56342, saving model to cnn_lstm_gtrends_weights_s1_i1.hdf5
# Epoch 202/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7392 - val_loss: 1.3309
#
# Epoch 00202: loss did not improve from 0.56342
# Epoch 203/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2829 - val_loss: 1.4069
#
# Epoch 00203: loss did not improve from 0.56342
# Epoch 204/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9945 - val_loss: 1.6013
#
# Epoch 00204: loss did not improve from 0.56342
# Epoch 205/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6373 - val_loss: 1.7883
#
# Epoch 00205: loss did not improve from 0.56342
# Epoch 206/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3538 - val_loss: 1.9153
#
# Epoch 00206: loss did not improve from 0.56342
# Epoch 207/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4901 - val_loss: 1.9821
#
# Epoch 00207: loss did not improve from 0.56342
# Epoch 208/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8018 - val_loss: 1.9859
#
# Epoch 00208: loss did not improve from 0.56342
# Epoch 209/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5359 - val_loss: 2.0063
#
# Epoch 00209: loss did not improve from 0.56342
# Epoch 210/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1194 - val_loss: 1.9543
#
# Epoch 00210: loss did not improve from 0.56342
# Epoch 211/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8385 - val_loss: 1.8688
#
# Epoch 00211: loss did not improve from 0.56342
# Epoch 212/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2042 - val_loss: 1.8013
#
# Epoch 00212: loss did not improve from 0.56342
# Epoch 213/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8155 - val_loss: 1.7702
#
# Epoch 00213: loss did not improve from 0.56342
# Epoch 214/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.5914 - val_loss: 1.7039
#
# Epoch 00214: loss did not improve from 0.56342
# Epoch 215/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1918 - val_loss: 1.6325
#
# Epoch 00215: loss did not improve from 0.56342
# Epoch 216/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8979 - val_loss: 1.6366
#
# Epoch 00216: loss did not improve from 0.56342
# Epoch 217/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2098 - val_loss: 1.6649
#
# Epoch 00217: loss did not improve from 0.56342
# Epoch 218/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.5336 - val_loss: 1.7047
#
# Epoch 00218: loss did not improve from 0.56342
# Epoch 219/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2401 - val_loss: 1.7442
#
# Epoch 00219: loss did not improve from 0.56342
# Epoch 220/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.6053 - val_loss: 1.7636
#
# Epoch 00220: loss did not improve from 0.56342
# Epoch 221/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0651 - val_loss: 1.8007
#
# Epoch 00221: loss did not improve from 0.56342
# Epoch 222/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8277 - val_loss: 1.7884
#
# Epoch 00222: loss did not improve from 0.56342
# Epoch 223/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5944 - val_loss: 1.7422
#
# Epoch 00223: loss did not improve from 0.56342
# Epoch 224/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5285 - val_loss: 1.6892
#
# Epoch 00224: loss improved from 0.56342 to 0.52848, saving model to cnn_lstm_gtrends_weights_s1_i1.hdf5
# Epoch 225/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0882 - val_loss: 1.6749
#
# Epoch 00225: loss did not improve from 0.52848
# Epoch 226/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9183 - val_loss: 1.6820
#
# Epoch 00226: loss did not improve from 0.52848
# Epoch 227/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.4119 - val_loss: 1.7054
#
# Epoch 00227: loss did not improve from 0.52848
# Epoch 228/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6246 - val_loss: 1.7420
#
# Epoch 00228: loss did not improve from 0.52848
# Epoch 229/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0741 - val_loss: 1.8116
#
# Epoch 00229: loss did not improve from 0.52848
# Epoch 230/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5280 - val_loss: 1.7778
#
# Epoch 00230: loss did not improve from 0.52848
# Epoch 231/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2908 - val_loss: 1.7395
#
# Epoch 00231: loss did not improve from 0.52848
# Epoch 232/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2215 - val_loss: 1.6770
#
# Epoch 00232: loss did not improve from 0.52848
# Epoch 233/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8193 - val_loss: 1.5898
#
# Epoch 00233: loss did not improve from 0.52848
# Epoch 234/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2117 - val_loss: 1.5606
#
# Epoch 00234: loss did not improve from 0.52848
# Epoch 235/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0735 - val_loss: 1.5175
#
# Epoch 00235: loss did not improve from 0.52848
# Epoch 236/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.7827 - val_loss: 1.4870
#
# Epoch 00236: loss did not improve from 0.52848
# Epoch 237/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4715 - val_loss: 1.4807
#
# Epoch 00237: loss did not improve from 0.52848
# Epoch 238/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.7934 - val_loss: 1.4844
#
# Epoch 00238: loss did not improve from 0.52848
# Epoch 239/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8232 - val_loss: 1.4743
#
# Epoch 00239: loss did not improve from 0.52848
# Epoch 240/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7781 - val_loss: 1.4712
#
# Epoch 00240: loss did not improve from 0.52848
# Epoch 241/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4040 - val_loss: 1.4517
#
# Epoch 00241: loss did not improve from 0.52848
# Epoch 242/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9175 - val_loss: 1.4855
#
# Epoch 00242: loss did not improve from 0.52848
# Epoch 243/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.5593 - val_loss: 1.5153
#
# Epoch 00243: loss did not improve from 0.52848
# Epoch 244/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6887 - val_loss: 1.5496
#
# Epoch 00244: loss did not improve from 0.52848
# Epoch 245/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7399 - val_loss: 1.5963
#
# Epoch 00245: loss did not improve from 0.52848
# Epoch 246/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1009 - val_loss: 1.5897
#
# Epoch 00246: loss did not improve from 0.52848
# Epoch 247/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9790 - val_loss: 1.6216
#
# Epoch 00247: loss did not improve from 0.52848
# Epoch 248/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1331 - val_loss: 1.7127
#
# Epoch 00248: loss did not improve from 0.52848
# Epoch 249/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3131 - val_loss: 1.8211
#
# Epoch 00249: loss did not improve from 0.52848
# Epoch 250/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0009 - val_loss: 2.0005
#
# Epoch 00250: loss did not improve from 0.52848
# Epoch 251/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.4650 - val_loss: 2.0843
#
# Epoch 00251: loss did not improve from 0.52848
# Epoch 252/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.8566 - val_loss: 2.1568
#
# Epoch 00252: loss did not improve from 0.52848
# Epoch 253/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1768 - val_loss: 2.1701
#
# Epoch 00253: loss did not improve from 0.52848
# Epoch 254/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5354 - val_loss: 2.1250
#
# Epoch 00254: loss did not improve from 0.52848
# Epoch 255/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.8593 - val_loss: 2.0421
#
# Epoch 00255: loss did not improve from 0.52848
# Epoch 256/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7312 - val_loss: 1.9233
#
# Epoch 00256: loss did not improve from 0.52848
# Epoch 257/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8913 - val_loss: 1.8575
#
# Epoch 00257: loss did not improve from 0.52848
# Epoch 258/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9963 - val_loss: 1.7543
#
# Epoch 00258: loss did not improve from 0.52848
# Epoch 259/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3537 - val_loss: 1.6416
#
# Epoch 00259: loss did not improve from 0.52848
# Epoch 260/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9986 - val_loss: 1.5164
#
# Epoch 00260: loss did not improve from 0.52848
# Epoch 261/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7910 - val_loss: 1.4295
#
# Epoch 00261: loss did not improve from 0.52848
# Epoch 262/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2341 - val_loss: 1.3776
#
# Epoch 00262: loss did not improve from 0.52848
# Epoch 263/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8344 - val_loss: 1.3416
#
# Epoch 00263: loss did not improve from 0.52848
# Epoch 264/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8923 - val_loss: 1.3481
#
# Epoch 00264: loss did not improve from 0.52848
# Epoch 265/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6980 - val_loss: 1.3366
#
# Epoch 00265: loss did not improve from 0.52848
# Epoch 266/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8235 - val_loss: 1.3690
#
# Epoch 00266: loss did not improve from 0.52848
# Epoch 267/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7318 - val_loss: 1.4032
#
# Epoch 00267: loss did not improve from 0.52848
# Epoch 268/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3172 - val_loss: 1.4818
#
# Epoch 00268: loss did not improve from 0.52848
# Epoch 269/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1201 - val_loss: 1.5600
#
# Epoch 00269: loss did not improve from 0.52848
# Epoch 270/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3374 - val_loss: 1.5751
#
# Epoch 00270: loss did not improve from 0.52848
# Epoch 271/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0206 - val_loss: 1.6152
#
# Epoch 00271: loss did not improve from 0.52848
# Epoch 272/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1943 - val_loss: 1.6376
#
# Epoch 00272: loss did not improve from 0.52848
# Epoch 273/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7332 - val_loss: 1.6782
#
# Epoch 00273: loss did not improve from 0.52848
# Epoch 274/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8726 - val_loss: 1.7152
#
# Epoch 00274: loss did not improve from 0.52848
# Epoch 275/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9174 - val_loss: 1.7530
#
# Epoch 00275: loss did not improve from 0.52848
# Epoch 276/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6989 - val_loss: 1.7679
#
# Epoch 00276: loss did not improve from 0.52848
# Epoch 277/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9202 - val_loss: 1.7433
#
# Epoch 00277: loss did not improve from 0.52848
# Epoch 278/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4412 - val_loss: 1.7239
#
# Epoch 00278: loss improved from 0.52848 to 0.44118, saving model to cnn_lstm_gtrends_weights_s1_i1.hdf5
# Epoch 279/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0273 - val_loss: 1.6984
#
# Epoch 00279: loss did not improve from 0.44118
# Epoch 280/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7684 - val_loss: 1.6655
#
# Epoch 00280: loss did not improve from 0.44118
# Epoch 281/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3447 - val_loss: 1.6015
#
# Epoch 00281: loss did not improve from 0.44118
# Epoch 282/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1141 - val_loss: 1.5118
#
# Epoch 00282: loss did not improve from 0.44118
# Epoch 283/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1037 - val_loss: 1.4059
#
# Epoch 00283: loss did not improve from 0.44118
# Epoch 284/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1617 - val_loss: 1.3657
#
# Epoch 00284: loss did not improve from 0.44118
# Epoch 285/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9485 - val_loss: 1.3266
#
# Epoch 00285: loss did not improve from 0.44118
# Epoch 286/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0218 - val_loss: 1.3928
#
# Epoch 00286: loss did not improve from 0.44118
# Epoch 287/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8055 - val_loss: 1.4300
#
# Epoch 00287: loss did not improve from 0.44118
# Epoch 288/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.9709 - val_loss: 1.4067
#
# Epoch 00288: loss did not improve from 0.44118
# Epoch 289/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4684 - val_loss: 1.3479
#
# Epoch 00289: loss did not improve from 0.44118
# Epoch 290/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0431 - val_loss: 1.4548
#
# Epoch 00290: loss did not improve from 0.44118
# Epoch 291/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4994 - val_loss: 1.5008
#
# Epoch 00291: loss did not improve from 0.44118
# Epoch 292/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0569 - val_loss: 1.5149
#
# Epoch 00292: loss did not improve from 0.44118
# Epoch 293/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0094 - val_loss: 1.5247
#
# Epoch 00293: loss did not improve from 0.44118
# Epoch 294/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8405 - val_loss: 1.5030
#
# Epoch 00294: loss did not improve from 0.44118
# Epoch 295/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5100 - val_loss: 1.5328
#
# Epoch 00295: loss did not improve from 0.44118
# Epoch 296/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5209 - val_loss: 1.8210
#
# Epoch 00296: loss did not improve from 0.44118
# Epoch 297/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.3274 - val_loss: 2.0399
#
# Epoch 00297: loss did not improve from 0.44118
# Epoch 298/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4339 - val_loss: 2.2045
#
# Epoch 00298: loss did not improve from 0.44118
# Epoch 299/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8484 - val_loss: 2.2853
#
# Epoch 00299: loss did not improve from 0.44118
# Epoch 300/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8409 - val_loss: 2.3654
#
# Epoch 00300: loss did not improve from 0.44118
# Epoch 301/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3262 - val_loss: 2.4020
#
# Epoch 00301: loss did not improve from 0.44118
# Epoch 302/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.5582 - val_loss: 2.3668
#
# Epoch 00302: loss did not improve from 0.44118
# Epoch 303/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8656 - val_loss: 2.2399
#
# Epoch 00303: loss did not improve from 0.44118
# Epoch 304/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7823 - val_loss: 2.0549
#
# Epoch 00304: loss did not improve from 0.44118
# Epoch 305/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.1688 - val_loss: 1.9078
#
# Epoch 00305: loss did not improve from 0.44118
# Epoch 306/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 2.9732 - val_loss: 1.7602
#
# Epoch 00306: loss did not improve from 0.44118
# Epoch 307/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2598 - val_loss: 1.5743
#
# Epoch 00307: loss did not improve from 0.44118
# Epoch 308/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7587 - val_loss: 1.4555
#
# Epoch 00308: loss did not improve from 0.44118
# Epoch 309/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7092 - val_loss: 1.3989
#
# Epoch 00309: loss did not improve from 0.44118
# Epoch 310/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 1.5192 - val_loss: 1.3820
#
# Epoch 00310: loss did not improve from 0.44118
# Epoch 311/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8897 - val_loss: 1.4039
#
# Epoch 00311: loss did not improve from 0.44118
# Epoch 312/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8561 - val_loss: 1.4035
#
# Epoch 00312: loss did not improve from 0.44118
# Epoch 313/5000
# ...
#
# Epoch 04895: loss did not improve from 0.02960
# Epoch 4896/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1053 - val_loss: 0.9959
#
# Epoch 04896: loss did not improve from 0.02960
# Epoch 4897/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2817 - val_loss: 0.9985
#
# Epoch 04897: loss did not improve from 0.02960
# Epoch 4898/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2118 - val_loss: 1.0010
#
# Epoch 04898: loss did not improve from 0.02960
# Epoch 4899/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1758 - val_loss: 1.0036
#
# Epoch 04899: loss did not improve from 0.02960
# Epoch 4900/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1366 - val_loss: 1.0058
#
# Epoch 04900: loss did not improve from 0.02960
# Epoch 4901/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2654 - val_loss: 1.0089
#
# Epoch 04901: loss did not improve from 0.02960
# Epoch 4902/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2403 - val_loss: 1.0115
#
# Epoch 04902: loss did not improve from 0.02960
# Epoch 4903/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0910 - val_loss: 1.0136
#
# Epoch 04903: loss did not improve from 0.02960
# Epoch 4904/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0438 - val_loss: 1.0153
#
# Epoch 04904: loss did not improve from 0.02960
# Epoch 4905/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3084 - val_loss: 1.0169
#
# Epoch 04905: loss did not improve from 0.02960
# Epoch 4906/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0546 - val_loss: 1.0186
#
# Epoch 04906: loss did not improve from 0.02960
# Epoch 4907/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3170 - val_loss: 1.0179
#
# Epoch 04907: loss did not improve from 0.02960
# Epoch 4908/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2548 - val_loss: 1.0188
#
# Epoch 04908: loss did not improve from 0.02960
# Epoch 4909/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0596 - val_loss: 1.0191
#
# Epoch 04909: loss did not improve from 0.02960
# Epoch 4910/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1437 - val_loss: 1.0193
#
# Epoch 04910: loss did not improve from 0.02960
# Epoch 4911/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2283 - val_loss: 1.0188
#
# Epoch 04911: loss did not improve from 0.02960
# Epoch 4912/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1081 - val_loss: 1.0182
#
# Epoch 04912: loss did not improve from 0.02960
# Epoch 4913/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3221 - val_loss: 1.0173
#
# Epoch 04913: loss did not improve from 0.02960
# Epoch 4914/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1869 - val_loss: 1.0162
#
# Epoch 04914: loss did not improve from 0.02960
# Epoch 4915/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1206 - val_loss: 1.0150
#
# Epoch 04915: loss did not improve from 0.02960
# Epoch 4916/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1382 - val_loss: 1.0139
#
# Epoch 04916: loss did not improve from 0.02960
# Epoch 4917/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1115 - val_loss: 1.0129
#
# Epoch 04917: loss did not improve from 0.02960
# Epoch 4918/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0796 - val_loss: 1.0119
#
# Epoch 04918: loss did not improve from 0.02960
# Epoch 4919/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1243 - val_loss: 1.0108
#
# Epoch 04919: loss did not improve from 0.02960
# Epoch 4920/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1548 - val_loss: 1.0102
#
# Epoch 04920: loss did not improve from 0.02960
# Epoch 4921/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3265 - val_loss: 1.0097
#
# Epoch 04921: loss did not improve from 0.02960
# Epoch 4922/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0740 - val_loss: 1.0092
#
# Epoch 04922: loss did not improve from 0.02960
# Epoch 4923/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1474 - val_loss: 1.0083
#
# Epoch 04923: loss did not improve from 0.02960
# Epoch 4924/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1561 - val_loss: 1.0074
#
# Epoch 04924: loss did not improve from 0.02960
# Epoch 4925/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3609 - val_loss: 1.0062
#
# Epoch 04925: loss did not improve from 0.02960
# Epoch 4926/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0459 - val_loss: 1.0049
#
# Epoch 04926: loss did not improve from 0.02960
# Epoch 4927/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3728 - val_loss: 1.0039
#
# Epoch 04927: loss did not improve from 0.02960
# Epoch 4928/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0968 - val_loss: 1.0032
#
# Epoch 04928: loss did not improve from 0.02960
# Epoch 4929/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0981 - val_loss: 1.0026
#
# Epoch 04929: loss did not improve from 0.02960
# Epoch 4930/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2261 - val_loss: 1.0023
#
# Epoch 04930: loss did not improve from 0.02960
# Epoch 4931/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1723 - val_loss: 1.0023
#
# Epoch 04931: loss did not improve from 0.02960
# Epoch 4932/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1719 - val_loss: 1.0019
#
# Epoch 04932: loss did not improve from 0.02960
# Epoch 4933/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2491 - val_loss: 1.0016
#
# Epoch 04933: loss did not improve from 0.02960
# Epoch 4934/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0626 - val_loss: 1.0015
#
# Epoch 04934: loss did not improve from 0.02960
# Epoch 4935/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1251 - val_loss: 1.0015
#
# Epoch 04935: loss did not improve from 0.02960
# Epoch 4936/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1085 - val_loss: 1.0015
#
# Epoch 04936: loss did not improve from 0.02960
# Epoch 4937/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1375 - val_loss: 1.0018
#
# Epoch 04937: loss did not improve from 0.02960
# Epoch 4938/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2815 - val_loss: 1.0013
#
# Epoch 04938: loss did not improve from 0.02960
# Epoch 4939/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1216 - val_loss: 1.0009
#
# Epoch 04939: loss did not improve from 0.02960
# Epoch 4940/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2641 - val_loss: 1.0007
#
# Epoch 04940: loss did not improve from 0.02960
# Epoch 4941/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1189 - val_loss: 1.0003
#
# Epoch 04941: loss did not improve from 0.02960
# Epoch 4942/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2942 - val_loss: 1.0002
#
# Epoch 04942: loss did not improve from 0.02960
# Epoch 4943/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1882 - val_loss: 1.0004
#
# Epoch 04943: loss did not improve from 0.02960
# Epoch 4944/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2251 - val_loss: 1.0006
#
# Epoch 04944: loss did not improve from 0.02960
# Epoch 4945/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0881 - val_loss: 1.0009
#
# Epoch 04945: loss did not improve from 0.02960
# Epoch 4946/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1198 - val_loss: 1.0014
#
# Epoch 04946: loss did not improve from 0.02960
# Epoch 4947/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1587 - val_loss: 1.0020
#
# Epoch 04947: loss did not improve from 0.02960
# Epoch 4948/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4095 - val_loss: 1.0023
#
# Epoch 04948: loss did not improve from 0.02960
# Epoch 4949/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2642 - val_loss: 1.0024
#
# Epoch 04949: loss did not improve from 0.02960
# Epoch 4950/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1904 - val_loss: 1.0024
#
# Epoch 04950: loss did not improve from 0.02960
# Epoch 4951/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0910 - val_loss: 1.0024
#
# Epoch 04951: loss did not improve from 0.02960
# Epoch 4952/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1593 - val_loss: 1.0023
#
# Epoch 04952: loss did not improve from 0.02960
# Epoch 4953/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0755 - val_loss: 1.0022
#
# Epoch 04953: loss did not improve from 0.02960
# Epoch 4954/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1589 - val_loss: 1.0021
#
# Epoch 04954: loss did not improve from 0.02960
# Epoch 4955/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1052 - val_loss: 1.0017
#
# Epoch 04955: loss did not improve from 0.02960
# Epoch 4956/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1476 - val_loss: 1.0010
#
# Epoch 04956: loss did not improve from 0.02960
# Epoch 4957/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0936 - val_loss: 1.0003
#
# Epoch 04957: loss did not improve from 0.02960
# Epoch 4958/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0555 - val_loss: 0.9995
#
# Epoch 04958: loss did not improve from 0.02960
# Epoch 4959/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0192 - val_loss: 0.9989
#
# Epoch 04959: loss improved from 0.02960 to 0.01920, saving model to cnn_lstm_gtrends_weights_s1_i1.hdf5
# Epoch 4960/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2296 - val_loss: 0.9984
#
# Epoch 04960: loss did not improve from 0.01920
# Epoch 4961/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1584 - val_loss: 0.9977
#
# Epoch 04961: loss did not improve from 0.01920
# Epoch 4962/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1948 - val_loss: 0.9967
#
# Epoch 04962: loss did not improve from 0.01920
# Epoch 4963/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2047 - val_loss: 0.9954
#
# Epoch 04963: loss did not improve from 0.01920
# Epoch 4964/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2431 - val_loss: 0.9943
#
# Epoch 04964: loss did not improve from 0.01920
# Epoch 4965/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2144 - val_loss: 0.9935
#
# Epoch 04965: loss did not improve from 0.01920
# Epoch 4966/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1987 - val_loss: 0.9926
#
# Epoch 04966: loss did not improve from 0.01920
# Epoch 4967/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1502 - val_loss: 0.9919
#
# Epoch 04967: loss did not improve from 0.01920
# Epoch 4968/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3645 - val_loss: 0.9913
#
# Epoch 04968: loss did not improve from 0.01920
# Epoch 4969/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1816 - val_loss: 0.9906
#
# Epoch 04969: loss did not improve from 0.01920
# Epoch 4970/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1929 - val_loss: 0.9905
#
# Epoch 04970: loss did not improve from 0.01920
# Epoch 4971/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2017 - val_loss: 0.9903
#
# Epoch 04971: loss did not improve from 0.01920
# Epoch 4972/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2700 - val_loss: 0.9903
#
# Epoch 04972: loss did not improve from 0.01920
# Epoch 4973/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2714 - val_loss: 0.9899
#
# Epoch 04973: loss did not improve from 0.01920
# Epoch 4974/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2690 - val_loss: 0.9893
#
# Epoch 04974: loss did not improve from 0.01920
# Epoch 4975/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1185 - val_loss: 0.9890
#
# Epoch 04975: loss did not improve from 0.01920
# Epoch 4976/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1624 - val_loss: 0.9886
#
# Epoch 04976: loss did not improve from 0.01920
# Epoch 4977/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1684 - val_loss: 0.9887
#
# Epoch 04977: loss did not improve from 0.01920
# Epoch 4978/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0327 - val_loss: 0.9887
#
# Epoch 04978: loss did not improve from 0.01920
# Epoch 4979/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1792 - val_loss: 0.9889
#
# Epoch 04979: loss did not improve from 0.01920
# Epoch 4980/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1653 - val_loss: 0.9891
#
# Epoch 04980: loss did not improve from 0.01920
# Epoch 4981/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2792 - val_loss: 0.9893
#
# Epoch 04981: loss did not improve from 0.01920
# Epoch 4982/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4245 - val_loss: 0.9895
#
# Epoch 04982: loss did not improve from 0.01920
# Epoch 4983/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1440 - val_loss: 0.9896
#
# Epoch 04983: loss did not improve from 0.01920
# Epoch 4984/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4572 - val_loss: 0.9895
#
# Epoch 04984: loss did not improve from 0.01920
# Epoch 4985/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1378 - val_loss: 0.9892
#
# Epoch 04985: loss did not improve from 0.01920
# Epoch 4986/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1432 - val_loss: 0.9890
#
# Epoch 04986: loss did not improve from 0.01920
# Epoch 4987/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1302 - val_loss: 0.9884
#
# Epoch 04987: loss did not improve from 0.01920
# Epoch 4988/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2075 - val_loss: 0.9879
#
# Epoch 04988: loss did not improve from 0.01920
# Epoch 4989/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0565 - val_loss: 0.9874
#
# Epoch 04989: loss did not improve from 0.01920
# Epoch 4990/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2305 - val_loss: 0.9871
#
# Epoch 04990: loss did not improve from 0.01920
# Epoch 4991/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1002 - val_loss: 0.9867
#
# Epoch 04991: loss did not improve from 0.01920
# Epoch 4992/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1149 - val_loss: 0.9865
#
# Epoch 04992: loss did not improve from 0.01920
# Epoch 4993/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5328 - val_loss: 0.9867
#
# Epoch 04993: loss did not improve from 0.01920
# Epoch 4994/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4402 - val_loss: 0.9868
#
# Epoch 04994: loss did not improve from 0.01920
# Epoch 4995/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3016 - val_loss: 0.9870
#
# Epoch 04995: loss did not improve from 0.01920
# Epoch 4996/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1844 - val_loss: 0.9878
#
# Epoch 04996: loss did not improve from 0.01920
# Epoch 4997/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3280 - val_loss: 0.9889
#
# Epoch 04997: loss did not improve from 0.01920
# Epoch 4998/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1158 - val_loss: 0.9907
#
# Epoch 04998: loss did not improve from 0.01920
# Epoch 4999/5000
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2805 - val_loss: 0.9917
#
# Epoch 04999: loss did not improve from 0.01920
# Epoch 5000/5000
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2320 - val_loss: 0.9922
#
# Epoch 05000: loss did not improve from 0.01920

# %%
#load from saved file
file_name = "cnn_lstm_gtrends_weights_s1_i1.hdf5"

model_cnn_lstm.load_weights(file_name)
model_cnn_lstm.compile(loss = 'mse', optimizer = 'adam')

#prediction
cnn_lstm_train_prediction = model_cnn_lstm.predict(X_train_series_sub)
cnn_lstm_test_prediction = model_cnn_lstm.predict(X_test_series_sub)

cnn_lstm_train_prediction
# Out:
# array([[2.7870297],
#        [2.0497937],
#        [2.1490927],
#        [3.385149 ],
#        [2.1342046],
#        [3.1199765],
#        [2.79609  ],
#        [2.1301422],
#        [2.1411006],
#        [2.8702884],
#        [3.5786223],
#        [4.0945334]], dtype=float32)

# %%
print('Train Error (RMSE):', np.sqrt(mean_squared_error(Y_train, cnn_lstm_train_prediction)))
print('Test Error (RMSE):', np.sqrt(mean_squared_error(Y_test, cnn_lstm_test_prediction)))
# Out:
# Train Error (RMSE): 0.2059442889789402
# Test Error (RMSE): 0.9994442677799859

# %%
#save to csv
date_format = "%Y-%m-%d"
a = datetime.strptime(train['Date'].max(), date_format)
a = a + timedelta(7)

next_date = str(datetime.date(a))
next_sales = np.round(cnn_lstm_train_prediction[len(cnn_lstm_train_prediction) - 1], 2)

dataset = dataset.append(pd.DataFrame({'Store' : '1',
                                       'Item' : '1',
                                       'Date' : next_date,
                                       'Weekly_Sales' : next_sales}))
dataset.tail()

# %%
dataset.to_csv('sales data-set.csv', index = False)
