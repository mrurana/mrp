# %%
import numpy as np
from tensorflow import set_random_seed
from numpy.random import seed
import pandas as pd
#import matplotlib.pyplot as plt
from keras import optimizers
from keras.callbacks import ModelCheckpoint
from keras.utils import plot_model
from keras.models import Sequential, Model
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers import Dense, LSTM, RepeatVector, TimeDistributed, Flatten, Dropout
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from datetime import datetime
from datetime import timedelta

# %%
#dataset_empty = 0
set_random_seed(1)
seed(1)

# %%
#Convert the train data into time series
def time_series_data(data, window, lag):
    dropnan = True
    cols, names = list(), list()

    for i in range(window, 0, -1):
        #past time series data (t-)
        cols.append(data.shift(i))
        names = names + [('%s(t-%d)' % (col, i)) for col in data.columns]
    
    #current time series data (t = 0)
    cols.append(data)
    names = names + [('%s(t)' % (col)) for col in data.columns]
    
    #future data (t + lag)
    cols.append(data.shift(-lag))
    names = names + [('%s(t+%d)' % (col, lag)) for col in data.columns]
    
    #all data
    all_data = pd.concat(cols, axis=1)
    all_data.columns = names
    
    #drops rows with NaN
    if dropnan:
        all_data.dropna(inplace=True)
    return all_data

# %%
dataset = pd.read_csv('sales data-set.csv', usecols = ['Store', 'Item', 'Date', 'Weekly_Sales'])
train = dataset[['Store', 'Item', 'Date', 'Weekly_Sales']]
#train = train.loc[(train['Store'] == 1) & (train['Item'] == 1)]
#train = train[(train['Date'] >= '2012-01-01')]
#train = train.loc[train['Store'] == 1]

print(train.head())
# Out:
#    Store  Item        Date  Weekly_Sales
# 0      1     1  2010-02-07      24924.50
# 1      1     2  2010-02-07      50605.27
# 2      1     3  2010-02-07      13740.12
# 3      1     4  2010-02-07      39954.04
# 4      1     5  2010-02-07      32229.38

# %%
#Re-arranges the train dataset to apply shift methods
train_r = train.sort_values('Date').groupby(['Item', 'Store', 'Date'], as_index=False)
train_r = train_r.agg({'Weekly_Sales':['mean']})
train_r.columns = ['Item', 'Store', 'Date', 'Weekly_Sales']
#cols_to_drop = ['Date']
#train_r.drop(cols_to_drop, axis=1, inplace=True)
train_r.head()
# Out:
#    Item  Store        Date  Weekly_Sales
# 0     1      1  2010-02-07      24924.50
# 1     1      1  2010-02-14      46039.49
# 2     1      1  2010-02-21      41595.55
# 3     1      1  2010-02-28      19403.54
# 4     1      1  2010-03-07      21827.90

# %%
train_r = train_r.groupby(['Date'], as_index=False)['Weekly_Sales'].sum()
train_r.head()
# Out:
#          Date  Weekly_Sales
# 0  2010-02-07   49750740.50
# 1  2010-02-14   48336677.63
# 2  2010-02-21   48276993.78
# 3  2010-02-28   43968571.13
# 4  2010-03-07   46871470.30

# %%
#weekly sales in 100 million dollars
train_r['Weekly_Sales'] = round(train_r['Weekly_Sales'] / 10000000, 2)
train_r.head()
# Out:
#          Date  Weekly_Sales
# 0  2010-02-07          4.98
# 1  2010-02-14          4.83
# 2  2010-02-21          4.83
# 3  2010-02-28          4.40
# 4  2010-03-07          4.69

# %%
#the model will use last 117 weekly sales data and 
#current timestep (7 days) to forecast next weekly sales data 12 weeks ahead

#the model will use last 29 weekly sales data and 
#current timestep (7 days) to forecast next weekly sales data 4 weeks ahead

window = 117
lag = 12

series_data = time_series_data(train_r, window, lag)
series_data.head()
# Out:
#     Date(t-117)  Weekly_Sales(t-117) Date(t-116)  Weekly_Sales(t-116)  \
# 117  2010-02-07                 4.98  2010-02-14                 4.83
# 118  2010-02-14                 4.83  2010-02-21                 4.83
# 119  2010-02-21                 4.83  2010-02-28                 4.40
# 120  2010-02-28                 4.40  2010-03-07                 4.69
# 121  2010-03-07                 4.69  2010-03-14                 4.59
#
#     Date(t-115)  Weekly_Sales(t-115) Date(t-114)  Weekly_Sales(t-114)  \
# 117  2010-02-21                 4.83  2010-02-28                 4.40
# 118  2010-02-28                 4.40  2010-03-07                 4.69
# 119  2010-03-07                 4.69  2010-03-14                 4.59
# 120  2010-03-14                 4.59  2010-03-21                 4.50
# 121  2010-03-21                 4.50  2010-03-28                 4.41
#
#     Date(t-113)  Weekly_Sales(t-113)  ...   Date(t-3)  Weekly_Sales(t-3)  \
# 117  2010-03-07                 4.69  ...  2012-04-15               4.66
# 118  2010-03-14                 4.59  ...  2012-04-22               4.51
# 119  2010-03-21                 4.50  ...  2012-04-29               4.37
# 120  2010-03-28                 4.41  ...  2012-05-06               4.71
# 121  2010-04-04                 5.04  ...  2012-05-13               4.69
#
#       Date(t-2)  Weekly_Sales(t-2)   Date(t-1)  Weekly_Sales(t-1)     Date(t)  \
# 117  2012-04-22               4.51  2012-04-29               4.37  2012-05-06
# 118  2012-04-29               4.37  2012-05-06               4.71  2012-05-13
# 119  2012-05-06               4.71  2012-05-13               4.69  2012-05-20
# 120  2012-05-13               4.69  2012-05-20               4.68  2012-05-27
# 121  2012-05-20               4.68  2012-05-27               4.79  2012-06-03
#
#      Weekly_Sales(t)  Date(t+12)  Weekly_Sales(t+12)
# 117             4.71  2012-07-29                4.41
# 118             4.69  2012-08-05                4.75
# 119             4.68  2012-08-12                4.74
# 120             4.79  2012-08-19                4.74
# 121             4.83  2012-08-26                4.74
#
# [5 rows x 238 columns]

# %%
future_dates = series_data[['Date(t+%d)' % lag]]
future_dates
# Out:
#      Date(t+12)
# 117  2012-07-29
# 118  2012-08-05
# 119  2012-08-12
# 120  2012-08-19
# 121  2012-08-26
# 122  2012-09-02
# 123  2012-09-09
# 124  2012-09-16
# 125  2012-09-23
# 126  2012-09-30
# 127  2012-10-07
# 128  2012-10-14
# 129  2012-10-21
# 130  2012-10-28

# %%
#drops last record of (t + lag)
#last_record_item = 'Item(t-%d)' % window
#last_record_store = 'Store(t-%d)' % window
#series_data = series_data[(series_data['Item(t)'] == series_data[last_record_item])]
#series_data = series_data[(series_data['Store(t)'] == series_data[last_record_store])]

#drops Item and Store columns
cols_to_drop = [('%s(t+%d)' % (col, lag)) for col in ['Date']]
for i in range(window, 0, -1):
    cols_to_drop += [('%s(t-%d)' % (col, i)) for col in ['Date']]

series_data.drop(cols_to_drop, axis=1, inplace=True)
series_data.drop(['Date(t)'], axis=1, inplace=True)

lbls_col = 'Weekly_Sales(t+%d)' % lag
lbls = series_data[lbls_col]
series_data = series_data.drop(lbls_col, axis=1)

series_data.head()
# Out:
#      Weekly_Sales(t-117)  Weekly_Sales(t-116)  Weekly_Sales(t-115)  \
# 117                 4.98                 4.83                 4.83
# 118                 4.83                 4.83                 4.40
# 119                 4.83                 4.40                 4.69
# 120                 4.40                 4.69                 4.59
# 121                 4.69                 4.59                 4.50
#
#      Weekly_Sales(t-114)  Weekly_Sales(t-113)  Weekly_Sales(t-112)  \
# 117                 4.40                 4.69                 4.59
# 118                 4.69                 4.59                 4.50
# 119                 4.59                 4.50                 4.41
# 120                 4.50                 4.41                 5.04
# 121                 4.41                 5.04                 4.74
#
#      Weekly_Sales(t-111)  Weekly_Sales(t-110)  Weekly_Sales(t-109)  \
# 117                 4.50                 4.41                 5.04
# 118                 4.41                 5.04                 4.74
# 119                 5.04                 4.74                 4.52
# 120                 4.74                 4.52                 4.47
# 121                 4.52                 4.47                 4.37
#
#      Weekly_Sales(t-108)  ...  Weekly_Sales(t-9)  Weekly_Sales(t-8)  \
# 117                 4.74  ...               4.69               4.75
# 118                 4.52  ...               4.75               4.69
# 119                 4.47  ...               4.69               4.50
# 120                 4.37  ...               4.50               4.53
# 121                 4.85  ...               4.53               5.35
#
#      Weekly_Sales(t-7)  Weekly_Sales(t-6)  Weekly_Sales(t-5)  \
# 117               4.69               4.50               4.53
# 118               4.50               4.53               5.35
# 119               4.53               5.35               4.66
# 120               5.35               4.66               4.51
# 121               4.66               4.51               4.37
#
#      Weekly_Sales(t-4)  Weekly_Sales(t-3)  Weekly_Sales(t-2)  \
# 117               5.35               4.66               4.51
# 118               4.66               4.51               4.37
# 119               4.51               4.37               4.71
# 120               4.37               4.71               4.69
# 121               4.71               4.69               4.68
#
#      Weekly_Sales(t-1)  Weekly_Sales(t)
# 117               4.37             4.71
# 118               4.71             4.69
# 119               4.69             4.68
# 120               4.68             4.79
# 121               4.79             4.83
#
# [5 rows x 118 columns]

# %%
series_data.shape[0]
# Out:
# 14

# %%
#train and test split

X_train_1, X_test_1, Y_train_1, Y_test_1 = train_test_split(series_data, lbls.values, test_size=0.1, random_state=0)
X_train = X_train_1
Y_train = Y_train_1

X_train_1, X_test_1, Y_train_1, Y_test_1 = train_test_split(series_data, lbls.values, test_size=0.5, random_state=0)
X_test = X_test_1
Y_test = Y_test_1

print('Train dataset:', X_train.shape)
print('Test dataset:', X_test.shape)
X_train.head()
# Out:
# Train dataset: (12, 118)
# Test dataset: (7, 118)
#      Weekly_Sales(t-117)  Weekly_Sales(t-116)  Weekly_Sales(t-115)  \
# 121                 4.69                 4.59                 4.50
# 128                 4.47                 4.37                 4.85
# 119                 4.83                 4.40                 4.69
# 130                 4.85                 4.53                 4.51
# 126                 4.74                 4.52                 4.47
#
#      Weekly_Sales(t-114)  Weekly_Sales(t-113)  Weekly_Sales(t-112)  \
# 121                 4.41                 5.04                 4.74
# 128                 4.53                 4.51                 4.78
# 119                 4.59                 4.50                 4.41
# 130                 4.78                 5.02                 4.78
# 126                 4.37                 4.85                 4.53
#
#      Weekly_Sales(t-111)  Weekly_Sales(t-110)  Weekly_Sales(t-109)  \
# 121                 4.52                 4.47                 4.37
# 128                 5.02                 4.78                 4.76
# 119                 5.04                 4.74                 4.52
# 130                 4.76                 4.66                 4.89
# 126                 4.51                 4.78                 5.02
#
#      Weekly_Sales(t-108)  ...  Weekly_Sales(t-9)  Weekly_Sales(t-8)  \
# 121                 4.85  ...               4.53               5.35
# 128                 4.66  ...               4.68               4.79
# 119                 4.47  ...               4.69               4.50
# 130                 4.79  ...               4.83               4.97
# 126                 4.78  ...               4.71               4.69
#
#      Weekly_Sales(t-7)  Weekly_Sales(t-6)  Weekly_Sales(t-5)  \
# 121               4.66               4.51               4.37
# 128               4.83               4.97               4.84
# 119               4.53               5.35               4.66
# 130               4.84               4.77               4.66
# 126               4.68               4.79               4.83
#
#      Weekly_Sales(t-4)  Weekly_Sales(t-3)  Weekly_Sales(t-2)  \
# 121               4.71               4.69               4.68
# 128               4.77               4.66               5.13
# 119               4.51               4.37               4.71
# 130               5.13               4.61               4.61
# 126               4.97               4.84               4.77
#
#      Weekly_Sales(t-1)  Weekly_Sales(t)
# 121               4.79             4.83
# 128               4.61             4.61
# 119               4.69             4.68
# 130               4.41             4.75
# 126               4.66             5.13
#
# [5 rows x 118 columns]

# %%
X_train_series = X_train.values.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_series = X_test.values.reshape((X_test.shape[0], X_test.shape[1], 1))
print('Train dataset:', X_train_series.shape)
print('Test dataset:', X_test_series.shape)
# Out:
# Train dataset: (12, 118, 1)
# Test dataset: (7, 118, 1)

# %%
#CNN-LSTM
subsequences = 2
time_steps = X_train_series.shape[1] // subsequences
X_train_series_sub = X_train_series.reshape((X_train_series.shape[0], subsequences, time_steps, 1))
X_test_series_sub = X_test_series.reshape((X_test_series.shape[0], subsequences, time_steps, 1))
print('Train dataset:', X_train_series_sub.shape)
print('Test dataset:', X_test_series_sub.shape)
# Out:
# Train dataset: (12, 2, 59, 1)
# Test dataset: (7, 2, 59, 1)

# %%
epochs = 15000
batch = 32
learning_rate = 0.00000001
adam = optimizers.Adam(learning_rate)

# %%
model_cnn_lstm = Sequential()
model_cnn_lstm.add(TimeDistributed(Conv1D(filters = 64, kernel_size = 1, activation = 'relu'), input_shape = (None, X_train_series_sub.shape[2], X_train_series_sub.shape[3])))
model_cnn_lstm.add(TimeDistributed(MaxPooling1D(pool_size=2)))
model_cnn_lstm.add(TimeDistributed(Flatten()))
model_cnn_lstm.add(LSTM(60, activation = 'relu'))
model_cnn_lstm.add(Dropout(0.1))
#model_cnn_lstm.add(Dense(100, activation='relu'))
#model_cnn_lstm.add(Dropout(0.4))
#model_cnn_lstm.add(Dense(50, activation='relu'))
#model_cnn_lstm.add(Dropout(0.3))
#model_cnn_lstm.add(Dense(32, activation='relu'))
#model_cnn_lstm.add(Dense(16, activation='relu'))
model_cnn_lstm.add(Dense(30, activation = 'relu'))
model_cnn_lstm.add(Dropout(0.1))
model_cnn_lstm.add(Dense(1))
model_cnn_lstm.compile(loss = 'mse', optimizer = 'adam')
model_cnn_lstm.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_13 (TimeDis (None, None, 59, 64)      128
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, None, 29, 64)      0
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, None, 1856)        0
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 60)                460080
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 30)                1830
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 30)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 462,069
# Trainable params: 462,069
# Non-trainable params: 0
# _________________________________________________________________

# %%
file_name = "cnn_lstm_weights_store_all.hdf5"    #saves file to create checkpoints for each epoch
checkpoint = ModelCheckpoint(file_name, monitor = 'loss', verbose = 1, save_best_only = True, mode = 'min')
callbacks_list = [checkpoint]

print('Please wait...')

cnn_lstm = model_cnn_lstm.fit(X_train_series_sub, Y_train, validation_data = (X_test_series_sub, Y_test), epochs = epochs, verbose = 1, callbacks = callbacks_list, batch_size = batch)
# Out:
# Please wait...
# Train on 12 samples, validate on 7 samples
# Epoch 1/15000
# 12/12 [==============================] - 1s 83ms/step - loss: 20.2491 - val_loss: 8.2608
#
# Epoch 00001: loss improved from inf to 20.24912, saving model to cnn_lstm_weights_store_all.hdf5
# Epoch 2/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 7.0981 - val_loss: 0.0699
#
# Epoch 00002: loss improved from 20.24912 to 7.09808, saving model to cnn_lstm_weights_store_all.hdf5
# Epoch 3/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7322 - val_loss: 6.7148
#
# Epoch 00003: loss improved from 7.09808 to 0.73218, saving model to cnn_lstm_weights_store_all.hdf5
# Epoch 4/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 8.9204 - val_loss: 1.6336
#
# Epoch 00004: loss did not improve from 0.73218
# Epoch 5/15000
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2157 - val_loss: 0.1243
#
# Epoch 00005: loss did not improve from 0.73218
# Epoch 6/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1935 - val_loss: 2.0110
#
# Epoch 00006: loss improved from 0.73218 to 0.19347, saving model to cnn_lstm_weights_store_all.hdf5
# Epoch 7/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 2.3510 - val_loss: 2.9206
#
# Epoch 00007: loss did not improve from 0.19347
# Epoch 8/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 3.5824 - val_loss: 2.3096
#
# Epoch 00008: loss did not improve from 0.19347
# Epoch 9/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 2.8048 - val_loss: 1.3600
#
# Epoch 00009: loss did not improve from 0.19347
# Epoch 10/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.7063 - val_loss: 0.4970
#
# Epoch 00010: loss did not improve from 0.19347
# Epoch 11/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7416 - val_loss: 0.0638
#
# Epoch 00011: loss did not improve from 0.19347
# Epoch 12/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.2188 - val_loss: 0.1394
#
# Epoch 00012: loss did not improve from 0.19347
# Epoch 13/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8877 - val_loss: 0.4242
#
# Epoch 00013: loss did not improve from 0.19347
# Epoch 14/15000
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2119 - val_loss: 0.6493
#
# Epoch 00014: loss did not improve from 0.19347
# Epoch 15/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 2.3328 - val_loss: 0.3648
#
# Epoch 00015: loss did not improve from 0.19347
# Epoch 16/15000
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6179 - val_loss: 0.0842
#
# Epoch 00016: loss did not improve from 0.19347
# Epoch 17/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.1043 - val_loss: 0.0575
#
# Epoch 00017: loss did not improve from 0.19347
# Epoch 18/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6915 - val_loss: 0.3223
#
# Epoch 00018: loss did not improve from 0.19347
# Epoch 19/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5922 - val_loss: 0.7929
#
# Epoch 00019: loss did not improve from 0.19347
# Epoch 20/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.3952 - val_loss: 1.1519
#
# Epoch 00020: loss did not improve from 0.19347
# Epoch 21/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.8286 - val_loss: 0.9503
#
# Epoch 00021: loss did not improve from 0.19347
# Epoch 22/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7023 - val_loss: 0.5535
#
# Epoch 00022: loss did not improve from 0.19347
# Epoch 23/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 2.5181 - val_loss: 0.1573
#
# Epoch 00023: loss did not improve from 0.19347
# Epoch 24/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5810 - val_loss: 0.0457
#
# Epoch 00024: loss did not improve from 0.19347
# Epoch 25/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4612 - val_loss: 0.0369
#
# Epoch 00025: loss did not improve from 0.19347
# Epoch 26/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0277 - val_loss: 0.0439
#
# Epoch 00026: loss did not improve from 0.19347
# Epoch 27/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0508 - val_loss: 0.0404
#
# Epoch 00027: loss did not improve from 0.19347
# Epoch 28/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5909 - val_loss: 0.0347
#
# Epoch 00028: loss did not improve from 0.19347
# Epoch 29/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8946 - val_loss: 0.0576
#
# Epoch 00029: loss did not improve from 0.19347
# Epoch 30/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9307 - val_loss: 0.1351
#
# Epoch 00030: loss did not improve from 0.19347
# Epoch 31/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4657 - val_loss: 0.1810
#
# Epoch 00031: loss did not improve from 0.19347
# Epoch 32/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4271 - val_loss: 0.1642
#
# Epoch 00032: loss did not improve from 0.19347
# Epoch 33/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.4371 - val_loss: 0.1030
#
# Epoch 00033: loss did not improve from 0.19347
# Epoch 34/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.2027 - val_loss: 0.0703
#
# Epoch 00034: loss did not improve from 0.19347
# Epoch 35/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2798 - val_loss: 0.0719
#
# Epoch 00035: loss did not improve from 0.19347
# Epoch 36/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6402 - val_loss: 0.0857
#
# Epoch 00036: loss did not improve from 0.19347
# Epoch 37/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0936 - val_loss: 0.0941
#
# Epoch 00037: loss did not improve from 0.19347
# Epoch 38/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3564 - val_loss: 0.0937
#
# Epoch 00038: loss did not improve from 0.19347
# Epoch 39/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4881 - val_loss: 0.1200
#
# Epoch 00039: loss did not improve from 0.19347
# Epoch 40/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8547 - val_loss: 0.1389
#
# Epoch 00040: loss did not improve from 0.19347
# Epoch 41/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4123 - val_loss: 0.1281
#
# Epoch 00041: loss did not improve from 0.19347
# Epoch 42/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5693 - val_loss: 0.0960
#
# Epoch 00042: loss did not improve from 0.19347
# Epoch 43/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9190 - val_loss: 0.0562
#
# Epoch 00043: loss did not improve from 0.19347
# Epoch 44/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3817 - val_loss: 0.0362
#
# Epoch 00044: loss did not improve from 0.19347
# Epoch 45/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2962 - val_loss: 0.0301
#
# Epoch 00045: loss did not improve from 0.19347
# Epoch 46/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6424 - val_loss: 0.0310
#
# Epoch 00046: loss did not improve from 0.19347
# Epoch 47/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7359 - val_loss: 0.0305
#
# Epoch 00047: loss did not improve from 0.19347
# Epoch 48/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7653 - val_loss: 0.0389
#
# Epoch 00048: loss did not improve from 0.19347
# Epoch 49/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6397 - val_loss: 0.1026
#
# Epoch 00049: loss did not improve from 0.19347
# Epoch 50/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9535 - val_loss: 0.2354
#
# Epoch 00050: loss did not improve from 0.19347
# Epoch 51/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2530 - val_loss: 0.4600
#
# Epoch 00051: loss did not improve from 0.19347
# Epoch 52/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4410 - val_loss: 0.5836
#
# Epoch 00052: loss did not improve from 0.19347
# Epoch 53/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.1600 - val_loss: 0.5231
#
# Epoch 00053: loss did not improve from 0.19347
# Epoch 54/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.1350 - val_loss: 0.2966
#
# Epoch 00054: loss did not improve from 0.19347
# Epoch 55/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.3996 - val_loss: 0.0698
#
# Epoch 00055: loss did not improve from 0.19347
# Epoch 56/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3893 - val_loss: 0.0563
#
# Epoch 00056: loss did not improve from 0.19347
# Epoch 57/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8456 - val_loss: 0.1122
#
# Epoch 00057: loss did not improve from 0.19347
# Epoch 58/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.5874 - val_loss: 0.1327
#
# Epoch 00058: loss did not improve from 0.19347
# Epoch 59/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7039 - val_loss: 0.0638
#
# Epoch 00059: loss did not improve from 0.19347
# Epoch 60/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9343 - val_loss: 0.0285
#
# Epoch 00060: loss did not improve from 0.19347
# Epoch 61/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6695 - val_loss: 0.0347
#
# Epoch 00061: loss did not improve from 0.19347
# Epoch 62/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5875 - val_loss: 0.0456
#
# Epoch 00062: loss did not improve from 0.19347
# Epoch 63/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2655 - val_loss: 0.0892
#
# Epoch 00063: loss did not improve from 0.19347
# Epoch 64/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3700 - val_loss: 0.1126
#
# Epoch 00064: loss did not improve from 0.19347
# Epoch 65/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2404 - val_loss: 0.1533
#
# Epoch 00065: loss did not improve from 0.19347
# Epoch 66/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2850 - val_loss: 0.1392
#
# Epoch 00066: loss did not improve from 0.19347
# Epoch 67/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1445 - val_loss: 0.1550
#
# Epoch 00067: loss improved from 0.19347 to 0.14445, saving model to cnn_lstm_weights_store_all.hdf5
# Epoch 68/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0863 - val_loss: 0.1847
#
# Epoch 00068: loss improved from 0.14445 to 0.08628, saving model to cnn_lstm_weights_store_all.hdf5
# Epoch 69/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6288 - val_loss: 0.1971
#
# Epoch 00069: loss did not improve from 0.08628
# Epoch 70/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3144 - val_loss: 0.1755
#
# Epoch 00070: loss did not improve from 0.08628
# Epoch 71/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3686 - val_loss: 0.1596
#
# Epoch 00071: loss did not improve from 0.08628
# Epoch 72/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4939 - val_loss: 0.1029
#
# Epoch 00072: loss did not improve from 0.08628
# Epoch 73/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4611 - val_loss: 0.0365
#
# Epoch 00073: loss did not improve from 0.08628
# Epoch 74/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4525 - val_loss: 0.0141
#
# Epoch 00074: loss did not improve from 0.08628
# Epoch 75/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3979 - val_loss: 0.0176
#
# Epoch 00075: loss did not improve from 0.08628
# Epoch 76/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6382 - val_loss: 0.0168
#
# Epoch 00076: loss did not improve from 0.08628
# Epoch 77/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6704 - val_loss: 0.1246
#
# Epoch 00077: loss did not improve from 0.08628
# Epoch 78/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3991 - val_loss: 0.5100
#
# Epoch 00078: loss did not improve from 0.08628
# Epoch 79/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7135 - val_loss: 0.6473
#
# Epoch 00079: loss did not improve from 0.08628
# Epoch 80/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8897 - val_loss: 0.3034
#
# Epoch 00080: loss did not improve from 0.08628
# Epoch 81/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6910 - val_loss: 0.0454
#
# Epoch 00081: loss did not improve from 0.08628
# Epoch 82/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6459 - val_loss: 0.0430
#
# Epoch 00082: loss did not improve from 0.08628
# Epoch 83/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3854 - val_loss: 0.0903
#
# Epoch 00083: loss did not improve from 0.08628
# Epoch 84/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5208 - val_loss: 0.0365
#
# Epoch 00084: loss did not improve from 0.08628
# Epoch 85/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5816 - val_loss: 0.0464
#
# Epoch 00085: loss did not improve from 0.08628
# Epoch 86/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5731 - val_loss: 0.1906
#
# Epoch 00086: loss did not improve from 0.08628
# Epoch 87/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6608 - val_loss: 0.2561
#
# Epoch 00087: loss did not improve from 0.08628
# Epoch 88/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4934 - val_loss: 0.2313
#
# Epoch 00088: loss did not improve from 0.08628
# Epoch 89/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4315 - val_loss: 0.1395
#
# Epoch 00089: loss did not improve from 0.08628
# Epoch 90/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.1479 - val_loss: 0.0238
#
# Epoch 00090: loss did not improve from 0.08628
# Epoch 91/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3655 - val_loss: 0.0331
#
# Epoch 00091: loss did not improve from 0.08628
# Epoch 92/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8088 - val_loss: 0.0620
#
# Epoch 00092: loss did not improve from 0.08628
# Epoch 93/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6715 - val_loss: 0.0265
#
# Epoch 00093: loss did not improve from 0.08628
# Epoch 94/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3424 - val_loss: 0.0946
#
# Epoch 00094: loss did not improve from 0.08628
# Epoch 95/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2875 - val_loss: 0.1896
#
# Epoch 00095: loss did not improve from 0.08628
# Epoch 96/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7816 - val_loss: 0.1889
#
# Epoch 00096: loss did not improve from 0.08628
# Epoch 97/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4179 - val_loss: 0.1370
#
# Epoch 00097: loss did not improve from 0.08628
# Epoch 98/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7426 - val_loss: 0.0756
#
# Epoch 00098: loss did not improve from 0.08628
# Epoch 99/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8803 - val_loss: 0.1043
#
# Epoch 00099: loss did not improve from 0.08628
# Epoch 100/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4420 - val_loss: 0.0759
#
# Epoch 00100: loss did not improve from 0.08628
# Epoch 101/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7873 - val_loss: 0.0432
#
# Epoch 00101: loss did not improve from 0.08628
# Epoch 102/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3258 - val_loss: 0.0397
#
# Epoch 00102: loss did not improve from 0.08628
# Epoch 103/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4131 - val_loss: 0.0695
#
# Epoch 00103: loss did not improve from 0.08628
# Epoch 104/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5883 - val_loss: 0.1775
#
# Epoch 00104: loss did not improve from 0.08628
# Epoch 105/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3216 - val_loss: 0.2974
#
# Epoch 00105: loss did not improve from 0.08628
# Epoch 106/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4519 - val_loss: 0.3080
#
# Epoch 00106: loss did not improve from 0.08628
# Epoch 107/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6194 - val_loss: 0.1994
#
# Epoch 00107: loss did not improve from 0.08628
# Epoch 108/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2933 - val_loss: 0.1145
#
# Epoch 00108: loss did not improve from 0.08628
# Epoch 109/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2800 - val_loss: 0.0403
#
# Epoch 00109: loss did not improve from 0.08628
# Epoch 110/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1387 - val_loss: 0.0238
#
# Epoch 00110: loss did not improve from 0.08628
# Epoch 111/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2951 - val_loss: 0.0270
#
# Epoch 00111: loss did not improve from 0.08628
# Epoch 112/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3036 - val_loss: 0.0244
#
# Epoch 00112: loss did not improve from 0.08628
# Epoch 113/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4466 - val_loss: 0.1764
#
# Epoch 00113: loss did not improve from 0.08628
# Epoch 114/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.1371 - val_loss: 0.3188
#
# Epoch 00114: loss did not improve from 0.08628
# Epoch 115/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4776 - val_loss: 0.3448
#
# Epoch 00115: loss did not improve from 0.08628
# Epoch 116/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3467 - val_loss: 0.3533
#
# Epoch 00116: loss did not improve from 0.08628
# Epoch 117/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2458 - val_loss: 0.2775
#
# Epoch 00117: loss did not improve from 0.08628
# Epoch 118/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1642 - val_loss: 0.1932
#
# Epoch 00118: loss did not improve from 0.08628
# Epoch 119/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1967 - val_loss: 0.1589
#
# Epoch 00119: loss did not improve from 0.08628
# Epoch 120/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3807 - val_loss: 0.1099
#
# Epoch 00120: loss did not improve from 0.08628
# Epoch 121/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5604 - val_loss: 0.0723
#
# Epoch 00121: loss did not improve from 0.08628
# Epoch 122/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2196 - val_loss: 0.0452
#
# Epoch 00122: loss did not improve from 0.08628
# Epoch 123/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1502 - val_loss: 0.0366
#
# Epoch 00123: loss did not improve from 0.08628
# Epoch 124/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0981 - val_loss: 0.0480
#
# Epoch 00124: loss did not improve from 0.08628
# Epoch 125/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1306 - val_loss: 0.0654
#
# Epoch 00125: loss did not improve from 0.08628
# Epoch 126/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1829 - val_loss: 0.1401
#
# Epoch 00126: loss did not improve from 0.08628
# Epoch 127/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5277 - val_loss: 0.2022
#
# Epoch 00127: loss did not improve from 0.08628
# Epoch 128/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3317 - val_loss: 0.1844
#
# Epoch 00128: loss did not improve from 0.08628
# Epoch 129/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7478 - val_loss: 0.1039
#
# Epoch 00129: loss did not improve from 0.08628
# Epoch 130/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1856 - val_loss: 0.0836
#
# Epoch 00130: loss did not improve from 0.08628
# Epoch 131/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7664 - val_loss: 0.0415
#
# Epoch 00131: loss did not improve from 0.08628
# Epoch 132/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.2446 - val_loss: 0.0388
#
# Epoch 00132: loss did not improve from 0.08628
# Epoch 133/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3017 - val_loss: 0.0836
#
# Epoch 00133: loss did not improve from 0.08628
# Epoch 134/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2750 - val_loss: 0.1270
#
# Epoch 00134: loss did not improve from 0.08628
# Epoch 135/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4059 - val_loss: 0.2012
#
# Epoch 00135: loss did not improve from 0.08628
# Epoch 136/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9225 - val_loss: 0.2125
#
# Epoch 00136: loss did not improve from 0.08628
# Epoch 137/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1848 - val_loss: 0.2148
#
# Epoch 00137: loss did not improve from 0.08628
# Epoch 138/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1085 - val_loss: 0.2652
#
# Epoch 00138: loss did not improve from 0.08628
# Epoch 139/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5306 - val_loss: 0.2817
#
# Epoch 00139: loss did not improve from 0.08628
# Epoch 140/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3182 - val_loss: 0.2316
#
# Epoch 00140: loss did not improve from 0.08628
# Epoch 141/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3972 - val_loss: 0.1648
#
# Epoch 00141: loss did not improve from 0.08628
# Epoch 142/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2985 - val_loss: 0.0768
#
# Epoch 00142: loss did not improve from 0.08628
# Epoch 143/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2894 - val_loss: 0.0577
#
# Epoch 00143: loss did not improve from 0.08628
# Epoch 144/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3045 - val_loss: 0.1078
#
# Epoch 00144: loss did not improve from 0.08628
# Epoch 145/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4273 - val_loss: 0.1366
#
# Epoch 00145: loss did not improve from 0.08628
# Epoch 146/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9375 - val_loss: 0.1417
#
# Epoch 00146: loss did not improve from 0.08628
# Epoch 147/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7365 - val_loss: 0.1334
#
# Epoch 00147: loss did not improve from 0.08628
# Epoch 148/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6067 - val_loss: 0.1754
#
# Epoch 00148: loss did not improve from 0.08628
# Epoch 149/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2219 - val_loss: 0.2049
#
# Epoch 00149: loss did not improve from 0.08628
# Epoch 150/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2153 - val_loss: 0.1802
#
# Epoch 00150: loss did not improve from 0.08628
# Epoch 151/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5515 - val_loss: 0.1308
#
# Epoch 00151: loss did not improve from 0.08628
# Epoch 152/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3353 - val_loss: 0.0812
#
# Epoch 00152: loss did not improve from 0.08628
# Epoch 153/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2407 - val_loss: 0.1131
#
# Epoch 00153: loss did not improve from 0.08628
# Epoch 154/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5378 - val_loss: 0.1334
#
# Epoch 00154: loss did not improve from 0.08628
# Epoch 155/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3080 - val_loss: 0.1251
#
# Epoch 00155: loss did not improve from 0.08628
# Epoch 156/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5901 - val_loss: 0.0908
#
# Epoch 00156: loss did not improve from 0.08628
# Epoch 157/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1549 - val_loss: 0.0477
#
# Epoch 00157: loss did not improve from 0.08628
# Epoch 158/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4670 - val_loss: 0.0339
#
# Epoch 00158: loss did not improve from 0.08628
# Epoch 159/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2710 - val_loss: 0.0560
#
# Epoch 00159: loss did not improve from 0.08628
# Epoch 160/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1930 - val_loss: 0.0743
#
# Epoch 00160: loss did not improve from 0.08628
# Epoch 161/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5468 - val_loss: 0.0621
#
# Epoch 00161: loss did not improve from 0.08628
# Epoch 162/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3341 - val_loss: 0.0582
#
# Epoch 00162: loss did not improve from 0.08628
# Epoch 163/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5949 - val_loss: 0.0709
#
# Epoch 00163: loss did not improve from 0.08628
# Epoch 164/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2841 - val_loss: 0.0994
#
# Epoch 00164: loss did not improve from 0.08628
# Epoch 165/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2078 - val_loss: 0.1820
#
# Epoch 00165: loss did not improve from 0.08628
# Epoch 166/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6275 - val_loss: 0.2035
#
# Epoch 00166: loss did not improve from 0.08628
# Epoch 167/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2483 - val_loss: 0.1473
#
# Epoch 00167: loss did not improve from 0.08628
# Epoch 168/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1286 - val_loss: 0.0743
#
# Epoch 00168: loss did not improve from 0.08628
# Epoch 169/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5037 - val_loss: 0.0253
#
# Epoch 00169: loss did not improve from 0.08628
# Epoch 170/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3307 - val_loss: 0.0229
#
# Epoch 00170: loss did not improve from 0.08628
# Epoch 171/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3837 - val_loss: 0.0344
#
# Epoch 00171: loss did not improve from 0.08628
# Epoch 172/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3279 - val_loss: 0.0972
#
# Epoch 00172: loss did not improve from 0.08628
# Epoch 173/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6051 - val_loss: 0.1695
#
# Epoch 00173: loss did not improve from 0.08628
# Epoch 174/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2732 - val_loss: 0.1542
#
# Epoch 00174: loss did not improve from 0.08628
# Epoch 175/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3623 - val_loss: 0.1201
#
# Epoch 00175: loss did not improve from 0.08628
# Epoch 176/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3080 - val_loss: 0.0994
#
# Epoch 00176: loss did not improve from 0.08628
# Epoch 177/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2390 - val_loss: 0.0870
#
# Epoch 00177: loss did not improve from 0.08628
# Epoch 178/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2078 - val_loss: 0.0816
#
# Epoch 00178: loss did not improve from 0.08628
# Epoch 179/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2184 - val_loss: 0.0608
#
# Epoch 00179: loss did not improve from 0.08628
# Epoch 180/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5115 - val_loss: 0.0615
#
# Epoch 00180: loss did not improve from 0.08628
# Epoch 181/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4778 - val_loss: 0.1111
#
# Epoch 00181: loss did not improve from 0.08628
# Epoch 182/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6545 - val_loss: 0.0959
#
# Epoch 00182: loss did not improve from 0.08628
# Epoch 183/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2932 - val_loss: 0.0720
#
# Epoch 00183: loss did not improve from 0.08628
# Epoch 184/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3167 - val_loss: 0.0895
#
# Epoch 00184: loss did not improve from 0.08628
# Epoch 185/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3715 - val_loss: 0.1187
#
# Epoch 00185: loss did not improve from 0.08628
# Epoch 186/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3147 - val_loss: 0.2001
#
# Epoch 00186: loss did not improve from 0.08628
# Epoch 187/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5422 - val_loss: 0.2414
#
# Epoch 00187: loss did not improve from 0.08628
# Epoch 188/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2929 - val_loss: 0.2328
#
# Epoch 00188: loss did not improve from 0.08628
# Epoch 189/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2924 - val_loss: 0.1946
#
# Epoch 00189: loss did not improve from 0.08628
# Epoch 190/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2308 - val_loss: 0.1314
#
# Epoch 00190: loss did not improve from 0.08628
# Epoch 191/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3830 - val_loss: 0.0787
#
# Epoch 00191: loss did not improve from 0.08628
# Epoch 192/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4437 - val_loss: 0.0544
#
# Epoch 00192: loss did not improve from 0.08628
# Epoch 193/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2963 - val_loss: 0.0654
#
# Epoch 00193: loss did not improve from 0.08628
# Epoch 194/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5092 - val_loss: 0.1118
#
# Epoch 00194: loss did not improve from 0.08628
# Epoch 195/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2935 - val_loss: 0.1954
#
# Epoch 00195: loss did not improve from 0.08628
# Epoch 196/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0908 - val_loss: 0.3681
#
# Epoch 00196: loss did not improve from 0.08628
# Epoch 197/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2480 - val_loss: 0.4042
#
# Epoch 00197: loss did not improve from 0.08628
# Epoch 198/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1089 - val_loss: 0.4833
#
# Epoch 00198: loss did not improve from 0.08628
# Epoch 199/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3729 - val_loss: 0.3841
#
# Epoch 00199: loss did not improve from 0.08628
# Epoch 200/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5252 - val_loss: 0.1882
#
# Epoch 00200: loss did not improve from 0.08628
# Epoch 201/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4578 - val_loss: 0.0592
#
# Epoch 00201: loss did not improve from 0.08628
# Epoch 202/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2242 - val_loss: 0.0313
#
# Epoch 00202: loss did not improve from 0.08628
# Epoch 203/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3870 - val_loss: 0.0375
#
# Epoch 00203: loss did not improve from 0.08628
# Epoch 204/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.0077 - val_loss: 0.0275
#
# Epoch 00204: loss did not improve from 0.08628
# Epoch 205/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4259 - val_loss: 0.0527
#
# Epoch 00205: loss did not improve from 0.08628
# Epoch 206/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3024 - val_loss: 0.1125
#
# Epoch 00206: loss did not improve from 0.08628
# Epoch 207/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2948 - val_loss: 0.1952
#
# Epoch 00207: loss did not improve from 0.08628
# Epoch 208/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6030 - val_loss: 0.2122
#
# Epoch 00208: loss did not improve from 0.08628
# Epoch 209/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1681 - val_loss: 0.2089
#
# Epoch 00209: loss did not improve from 0.08628
# Epoch 210/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3990 - val_loss: 0.1413
#
# Epoch 00210: loss did not improve from 0.08628
# Epoch 211/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1825 - val_loss: 0.1288
#
# Epoch 00211: loss did not improve from 0.08628
# Epoch 212/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4027 - val_loss: 0.0765
#
# Epoch 00212: loss did not improve from 0.08628
# Epoch 213/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1892 - val_loss: 0.1298
#
# Epoch 00213: loss did not improve from 0.08628
# Epoch 214/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2544 - val_loss: 0.1870
#
# Epoch 00214: loss did not improve from 0.08628
# Epoch 215/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5516 - val_loss: 0.2690
#
# Epoch 00215: loss did not improve from 0.08628
# Epoch 216/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5995 - val_loss: 0.2322
#
# Epoch 00216: loss did not improve from 0.08628
# Epoch 217/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1861 - val_loss: 0.1917
#
# Epoch 00217: loss did not improve from 0.08628
# Epoch 218/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.8053 - val_loss: 0.0866
#
# Epoch 00218: loss did not improve from 0.08628
# Epoch 219/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.4585 - val_loss: 0.0367
#
# Epoch 00219: loss did not improve from 0.08628
# Epoch 220/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.5657 - val_loss: 0.0315
#
# Epoch 00220: loss did not improve from 0.08628
# Epoch 221/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6815 - val_loss: 0.0545
#
# Epoch 00221: loss did not improve from 0.08628
# Epoch 222/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4660 - val_loss: 0.0943
#
# Epoch 00222: loss did not improve from 0.08628
# Epoch 223/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4263 - val_loss: 0.1843
#
# Epoch 00223: loss did not improve from 0.08628
# Epoch 224/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5183 - val_loss: 0.2256
#
# Epoch 00224: loss did not improve from 0.08628
# Epoch 225/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1130 - val_loss: 0.2576
#
# Epoch 00225: loss did not improve from 0.08628
# Epoch 226/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0561 - val_loss: 0.3020
#
# Epoch 00226: loss improved from 0.08628 to 0.05607, saving model to cnn_lstm_weights_store_all.hdf5
# Epoch 227/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6609 - val_loss: 0.2368
#
# Epoch 00227: loss did not improve from 0.05607
# Epoch 228/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.4379 - val_loss: 0.1421
#
# Epoch 00228: loss did not improve from 0.05607
# Epoch 229/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4974 - val_loss: 0.0343
#
# Epoch 00229: loss did not improve from 0.05607
# Epoch 230/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5369 - val_loss: 0.0142
#
# Epoch 00230: loss did not improve from 0.05607
# Epoch 231/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6150 - val_loss: 0.0362
#
# Epoch 00231: loss did not improve from 0.05607
# Epoch 232/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3526 - val_loss: 0.1482
#
# Epoch 00232: loss did not improve from 0.05607
# Epoch 233/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1816 - val_loss: 0.2786
#
# Epoch 00233: loss did not improve from 0.05607
# Epoch 234/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1971 - val_loss: 0.3549
#
# Epoch 00234: loss did not improve from 0.05607
# Epoch 235/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.1315 - val_loss: 0.3941
#
# Epoch 00235: loss did not improve from 0.05607
# Epoch 236/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5859 - val_loss: 0.3088
#
# Epoch 00236: loss did not improve from 0.05607
# Epoch 237/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1739 - val_loss: 0.2039
#
# Epoch 00237: loss did not improve from 0.05607
# Epoch 238/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.1972 - val_loss: 0.1706
#
# Epoch 00238: loss did not improve from 0.05607
# Epoch 239/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.3751 - val_loss: 0.1134
#
# Epoch 00239: loss did not improve from 0.05607
# Epoch 240/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1781 - val_loss: 0.1288
#
# Epoch 00240: loss did not improve from 0.05607
# Epoch 241/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2772 - val_loss: 0.1951
#
# Epoch 00241: loss did not improve from 0.05607
# Epoch 242/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2976 - val_loss: 0.2983
#
# Epoch 00242: loss did not improve from 0.05607
# Epoch 243/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4469 - val_loss: 0.3147
#
# Epoch 00243: loss did not improve from 0.05607
# Epoch 244/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9125 - val_loss: 0.2267
#
# Epoch 00244: loss did not improve from 0.05607
# Epoch 245/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2146 - val_loss: 0.1503
#
# Epoch 00245: loss did not improve from 0.05607
# Epoch 246/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5979 - val_loss: 0.0536
#
# Epoch 00246: loss did not improve from 0.05607
# Epoch 247/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4797 - val_loss: 0.0316
#
# Epoch 00247: loss did not improve from 0.05607
# Epoch 248/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3553 - val_loss: 0.0254
#
# Epoch 00248: loss did not improve from 0.05607
# Epoch 249/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4822 - val_loss: 0.1082
#
# Epoch 00249: loss did not improve from 0.05607
# Epoch 250/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2358 - val_loss: 0.2379
#
# Epoch 00250: loss did not improve from 0.05607
# Epoch 251/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6090 - val_loss: 0.2506
#
# Epoch 00251: loss did not improve from 0.05607
# Epoch 252/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.3214 - val_loss: 0.3231
#
# Epoch 00252: loss did not improve from 0.05607
# Epoch 253/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3185 - val_loss: 0.3269
#
# Epoch 00253: loss did not improve from 0.05607
# Epoch 254/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2251 - val_loss: 0.2852
#
# Epoch 00254: loss did not improve from 0.05607
# Epoch 255/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3032 - val_loss: 0.1839
#
# Epoch 00255: loss did not improve from 0.05607
# Epoch 256/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1804 - val_loss: 0.1324
#
# Epoch 00256: loss did not improve from 0.05607
# Epoch 257/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2530 - val_loss: 0.0748
#
# Epoch 00257: loss did not improve from 0.05607
# Epoch 258/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1128 - val_loss: 0.0806
#
# Epoch 00258: loss did not improve from 0.05607
# Epoch 259/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1987 - val_loss: 0.1455
#
# Epoch 00259: loss did not improve from 0.05607
# Epoch 260/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1799 - val_loss: 0.2096
#
# Epoch 00260: loss did not improve from 0.05607
# Epoch 261/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1497 - val_loss: 0.2986
#
# Epoch 00261: loss did not improve from 0.05607
# Epoch 262/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5680 - val_loss: 0.2591
#
# Epoch 00262: loss did not improve from 0.05607
# Epoch 263/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4019 - val_loss: 0.1457
#
# Epoch 00263: loss did not improve from 0.05607
# Epoch 264/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1673 - val_loss: 0.1008
#
# Epoch 00264: loss did not improve from 0.05607
# Epoch 265/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2530 - val_loss: 0.1130
#
# Epoch 00265: loss did not improve from 0.05607
# Epoch 266/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3025 - val_loss: 0.1511
#
# Epoch 00266: loss did not improve from 0.05607
# Epoch 267/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4114 - val_loss: 0.2141
#
# Epoch 00267: loss did not improve from 0.05607
# Epoch 268/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1739 - val_loss: 0.3144
#
# Epoch 00268: loss did not improve from 0.05607
# Epoch 269/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4129 - val_loss: 0.3752
#
# Epoch 00269: loss did not improve from 0.05607
# Epoch 270/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5464 - val_loss: 0.2380
#
# Epoch 00270: loss did not improve from 0.05607
# Epoch 271/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4189 - val_loss: 0.1017
#
# Epoch 00271: loss did not improve from 0.05607
# Epoch 272/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2237 - val_loss: 0.0640
#
# Epoch 00272: loss did not improve from 0.05607
# Epoch 273/15000
# 12/12 [==============================] - 0s 996us/step - loss: 0.3238 - val_loss: 0.0427
#
# Epoch 00273: loss did not improve from 0.05607
# Epoch 274/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3682 - val_loss: 0.1035
#
# Epoch 00274: loss did not improve from 0.05607
# Epoch 275/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2522 - val_loss: 0.3118
#
# Epoch 00275: loss did not improve from 0.05607
# Epoch 276/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3963 - val_loss: 0.4723
#
# Epoch 00276: loss did not improve from 0.05607
# Epoch 277/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.5925 - val_loss: 0.4890
#
# Epoch 00277: loss did not improve from 0.05607
# Epoch 278/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2969 - val_loss: 0.4175
#
# Epoch 00278: loss did not improve from 0.05607
# Epoch 279/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2319 - val_loss: 0.2988
#
# Epoch 00279: loss did not improve from 0.05607
# Epoch 280/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2215 - val_loss: 0.1510
#
# Epoch 00280: loss did not improve from 0.05607
# Epoch 281/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.2800 - val_loss: 0.0723
#
# Epoch 00281: loss did not improve from 0.05607
# Epoch 282/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4357 - val_loss: 0.0477
#
# Epoch 00282: loss did not improve from 0.05607
# Epoch 283/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7481 - val_loss: 0.0607
#
# Epoch 00283: loss did not improve from 0.05607
# Epoch 284/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.1885 - val_loss: 0.1125
#
# Epoch 00284: loss did not improve from 0.05607
# Epoch 285/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1968 - val_loss: 0.2027
#
# Epoch 00285: loss did not improve from 0.05607
# Epoch 286/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2248 - val_loss: 0.2788
#
# Epoch 00286: loss did not improve from 0.05607
# Epoch 287/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 1.2538 - val_loss: 0.2543
#
# Epoch 00287: loss did not improve from 0.05607
# Epoch 288/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.6624 - val_loss: 0.1587
#
# Epoch 00288: loss did not improve from 0.05607
# Epoch 289/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2998 - val_loss: 0.1191
#
# Epoch 00289: loss did not improve from 0.05607
# Epoch 290/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2539 - val_loss: 0.0523
#
# Epoch 00290: loss did not improve from 0.05607
# Epoch 291/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3560 - val_loss: 0.0226
#
# Epoch 00291: loss did not improve from 0.05607
# Epoch 292/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4631 - val_loss: 0.0359
#
# Epoch 00292: loss did not improve from 0.05607
# Epoch 293/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1989 - val_loss: 0.1023
#
# Epoch 00293: loss did not improve from 0.05607
# Epoch 294/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3660 - val_loss: 0.1848
#
# Epoch 00294: loss did not improve from 0.05607
# Epoch 295/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1317 - val_loss: 0.2940
#
# Epoch 00295: loss did not improve from 0.05607
# Epoch 296/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.7195 - val_loss: 0.2580
#
# Epoch 00296: loss did not improve from 0.05607
# Epoch 297/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0654 - val_loss: 0.2251
#
# Epoch 00297: loss did not improve from 0.05607
# Epoch 298/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4110 - val_loss: 0.1532
#
# Epoch 00298: loss did not improve from 0.05607
# Epoch 299/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.1300 - val_loss: 0.1297
#
# Epoch 00299: loss did not improve from 0.05607
# Epoch 300/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4662 - val_loss: 0.1150
#
# Epoch 00300: loss did not improve from 0.05607
# Epoch 301/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4010 - val_loss: 0.1221
#
# Epoch 00301: loss did not improve from 0.05607
# Epoch 302/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2313 - val_loss: 0.2320
#
# Epoch 00302: loss did not improve from 0.05607
# Epoch 303/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3545 - val_loss: 0.3845
#
# Epoch 00303: loss did not improve from 0.05607
# Epoch 304/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.9443 - val_loss: 0.4181
#
# Epoch 00304: loss did not improve from 0.05607
# Epoch 305/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.3416 - val_loss: 0.3162
#
# Epoch 00305: loss did not improve from 0.05607
# Epoch 306/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1990 - val_loss: 0.1638
#
# Epoch 00306: loss did not improve from 0.05607
# Epoch 307/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2238 - val_loss: 0.0907
#
# Epoch 00307: loss did not improve from 0.05607
# Epoch 308/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.8716 - val_loss: 0.0527
#
# Epoch 00308: loss did not improve from 0.05607
# Epoch 309/15000
# 12/12 [==============================] - 0s 998us/step - loss: 0.3304 - val_loss: 0.0856
#
# Epoch 00309: loss did not improve from 0.05607
# Epoch 310/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2464 - val_loss: 0.1830
#
# Epoch 00310: loss did not improve from 0.05607
# Epoch 311/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0790 - val_loss: 0.2932
#
# Epoch 00311: loss did not improve from 0.05607
# Epoch 312/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2957 - val_loss: 0.4040
#
# Epoch 00312: loss did not improve from 0.05607
# Epoch 313/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.4687 - val_loss: 0.3698
#
# Epoch 00313: loss did not improve from 0.05607
# Epoch 314/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.2160 - val_loss: 0.2911
#
# Epoch 00314: loss did not improve from 0.05607
# Epoch 315/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.4641 - val_loss: 0.1329
#
# Epoch 00315: loss did not improve from 0.05607
# Epoch 316/15000
# ...
#
# Epoch 13617: loss did not improve from 0.00532
# Epoch 13618/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0157 - val_loss: 0.0069
#
# Epoch 13618: loss did not improve from 0.00532
# Epoch 13619/15000
# 12/12 [==============================] - 0s 914us/step - loss: 0.0071 - val_loss: 0.0070
#
# Epoch 13619: loss did not improve from 0.00532
# Epoch 13620/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0193 - val_loss: 0.0074
#
# Epoch 13620: loss did not improve from 0.00532
# Epoch 13621/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0243 - val_loss: 0.0081
#
# Epoch 13621: loss did not improve from 0.00532
# Epoch 13622/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0181 - val_loss: 0.0091
#
# Epoch 13622: loss did not improve from 0.00532
# Epoch 13623/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0206 - val_loss: 0.0101
#
# Epoch 13623: loss did not improve from 0.00532
# Epoch 13624/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0226 - val_loss: 0.0109
#
# Epoch 13624: loss did not improve from 0.00532
# Epoch 13625/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0178 - val_loss: 0.0118
#
# Epoch 13625: loss did not improve from 0.00532
# Epoch 13626/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0195 - val_loss: 0.0128
#
# Epoch 13626: loss did not improve from 0.00532
# Epoch 13627/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0155 - val_loss: 0.0135
#
# Epoch 13627: loss did not improve from 0.00532
# Epoch 13628/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0171 - val_loss: 0.0141
#
# Epoch 13628: loss did not improve from 0.00532
# Epoch 13629/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0105 - val_loss: 0.0143
#
# Epoch 13629: loss did not improve from 0.00532
# Epoch 13630/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0299 - val_loss: 0.0137
#
# Epoch 13630: loss did not improve from 0.00532
# Epoch 13631/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0192 - val_loss: 0.0126
#
# Epoch 13631: loss did not improve from 0.00532
# Epoch 13632/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0236 - val_loss: 0.0113
#
# Epoch 13632: loss did not improve from 0.00532
# Epoch 13633/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0172 - val_loss: 0.0101
#
# Epoch 13633: loss did not improve from 0.00532
# Epoch 13634/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0375 - val_loss: 0.0089
#
# Epoch 13634: loss did not improve from 0.00532
# Epoch 13635/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0295 - val_loss: 0.0077
#
# Epoch 13635: loss did not improve from 0.00532
# Epoch 13636/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0221 - val_loss: 0.0069
#
# Epoch 13636: loss did not improve from 0.00532
# Epoch 13637/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0246 - val_loss: 0.0065
#
# Epoch 13637: loss did not improve from 0.00532
# Epoch 13638/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0153 - val_loss: 0.0064
#
# Epoch 13638: loss did not improve from 0.00532
# Epoch 13639/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0342 - val_loss: 0.0064
#
# Epoch 13639: loss did not improve from 0.00532
# Epoch 13640/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0208 - val_loss: 0.0064
#
# Epoch 13640: loss did not improve from 0.00532
# Epoch 13641/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0358 - val_loss: 0.0063
#
# Epoch 13641: loss did not improve from 0.00532
# Epoch 13642/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0133 - val_loss: 0.0062
#
# Epoch 13642: loss did not improve from 0.00532
# Epoch 13643/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0132 - val_loss: 0.0063
#
# Epoch 13643: loss did not improve from 0.00532
# Epoch 13644/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0254 - val_loss: 0.0066
#
# Epoch 13644: loss did not improve from 0.00532
# Epoch 13645/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0151 - val_loss: 0.0072
#
# Epoch 13645: loss did not improve from 0.00532
# Epoch 13646/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0452 - val_loss: 0.0079
#
# Epoch 13646: loss did not improve from 0.00532
# Epoch 13647/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0264 - val_loss: 0.0085
#
# Epoch 13647: loss did not improve from 0.00532
# Epoch 13648/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0200 - val_loss: 0.0092
#
# Epoch 13648: loss did not improve from 0.00532
# Epoch 13649/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0275 - val_loss: 0.0094
#
# Epoch 13649: loss did not improve from 0.00532
# Epoch 13650/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0136 - val_loss: 0.0096
#
# Epoch 13650: loss did not improve from 0.00532
# Epoch 13651/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0210 - val_loss: 0.0100
#
# Epoch 13651: loss did not improve from 0.00532
# Epoch 13652/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0169 - val_loss: 0.0108
#
# Epoch 13652: loss did not improve from 0.00532
# Epoch 13653/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0409 - val_loss: 0.0109
#
# Epoch 13653: loss did not improve from 0.00532
# Epoch 13654/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0409 - val_loss: 0.0110
#
# Epoch 13654: loss did not improve from 0.00532
# Epoch 13655/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0216 - val_loss: 0.0109
#
# Epoch 13655: loss did not improve from 0.00532
# Epoch 13656/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0161 - val_loss: 0.0107
#
# Epoch 13656: loss did not improve from 0.00532
# Epoch 13657/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0404 - val_loss: 0.0100
#
# Epoch 13657: loss did not improve from 0.00532
# Epoch 13658/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0411 - val_loss: 0.0093
#
# Epoch 13658: loss did not improve from 0.00532
# Epoch 13659/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0088 - val_loss: 0.0086
#
# Epoch 13659: loss did not improve from 0.00532
# Epoch 13660/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0146 - val_loss: 0.0084
#
# Epoch 13660: loss did not improve from 0.00532
# Epoch 13661/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0081
#
# Epoch 13661: loss did not improve from 0.00532
# Epoch 13662/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0134 - val_loss: 0.0080
#
# Epoch 13662: loss did not improve from 0.00532
# Epoch 13663/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0239 - val_loss: 0.0079
#
# Epoch 13663: loss did not improve from 0.00532
# Epoch 13664/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0220 - val_loss: 0.0078
#
# Epoch 13664: loss did not improve from 0.00532
# Epoch 13665/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0178 - val_loss: 0.0077
#
# Epoch 13665: loss did not improve from 0.00532
# Epoch 13666/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0173 - val_loss: 0.0076
#
# Epoch 13666: loss did not improve from 0.00532
# Epoch 13667/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0135 - val_loss: 0.0076
#
# Epoch 13667: loss did not improve from 0.00532
# Epoch 13668/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0329 - val_loss: 0.0076
#
# Epoch 13668: loss did not improve from 0.00532
# Epoch 13669/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0218 - val_loss: 0.0078
#
# Epoch 13669: loss did not improve from 0.00532
# Epoch 13670/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0269 - val_loss: 0.0084
#
# Epoch 13670: loss did not improve from 0.00532
# Epoch 13671/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0200 - val_loss: 0.0089
#
# Epoch 13671: loss did not improve from 0.00532
# Epoch 13672/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0153 - val_loss: 0.0093
#
# Epoch 13672: loss did not improve from 0.00532
# Epoch 13673/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0158 - val_loss: 0.0096
#
# Epoch 13673: loss did not improve from 0.00532
# Epoch 13674/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0190 - val_loss: 0.0100
#
# Epoch 13674: loss did not improve from 0.00532
# Epoch 13675/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0170 - val_loss: 0.0103
#
# Epoch 13675: loss did not improve from 0.00532
# Epoch 13676/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0184 - val_loss: 0.0101
#
# Epoch 13676: loss did not improve from 0.00532
# Epoch 13677/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0311 - val_loss: 0.0099
#
# Epoch 13677: loss did not improve from 0.00532
# Epoch 13678/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0330 - val_loss: 0.0094
#
# Epoch 13678: loss did not improve from 0.00532
# Epoch 13679/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0348 - val_loss: 0.0088
#
# Epoch 13679: loss did not improve from 0.00532
# Epoch 13680/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0611 - val_loss: 0.0081
#
# Epoch 13680: loss did not improve from 0.00532
# Epoch 13681/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0243 - val_loss: 0.0075
#
# Epoch 13681: loss did not improve from 0.00532
# Epoch 13682/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0162 - val_loss: 0.0072
#
# Epoch 13682: loss did not improve from 0.00532
# Epoch 13683/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0271 - val_loss: 0.0069
#
# Epoch 13683: loss did not improve from 0.00532
# Epoch 13684/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0251 - val_loss: 0.0069
#
# Epoch 13684: loss did not improve from 0.00532
# Epoch 13685/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0150 - val_loss: 0.0069
#
# Epoch 13685: loss did not improve from 0.00532
# Epoch 13686/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0271 - val_loss: 0.0068
#
# Epoch 13686: loss did not improve from 0.00532
# Epoch 13687/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0076 - val_loss: 0.0067
#
# Epoch 13687: loss did not improve from 0.00532
# Epoch 13688/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0176 - val_loss: 0.0067
#
# Epoch 13688: loss did not improve from 0.00532
# Epoch 13689/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0145 - val_loss: 0.0066
#
# Epoch 13689: loss did not improve from 0.00532
# Epoch 13690/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0105 - val_loss: 0.0066
#
# Epoch 13690: loss did not improve from 0.00532
# Epoch 13691/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0303 - val_loss: 0.0066
#
# Epoch 13691: loss did not improve from 0.00532
# Epoch 13692/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0155 - val_loss: 0.0067
#
# Epoch 13692: loss did not improve from 0.00532
# Epoch 13693/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0200 - val_loss: 0.0069
#
# Epoch 13693: loss did not improve from 0.00532
# Epoch 13694/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0194 - val_loss: 0.0070
#
# Epoch 13694: loss did not improve from 0.00532
# Epoch 13695/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0125 - val_loss: 0.0072
#
# Epoch 13695: loss did not improve from 0.00532
# Epoch 13696/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0139 - val_loss: 0.0074
#
# Epoch 13696: loss did not improve from 0.00532
# Epoch 13697/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0118 - val_loss: 0.0076
#
# Epoch 13697: loss did not improve from 0.00532
# Epoch 13698/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0177 - val_loss: 0.0079
#
# Epoch 13698: loss did not improve from 0.00532
# Epoch 13699/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0265 - val_loss: 0.0080
#
# Epoch 13699: loss did not improve from 0.00532
# Epoch 13700/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0087 - val_loss: 0.0081
#
# Epoch 13700: loss did not improve from 0.00532
# Epoch 13701/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0328 - val_loss: 0.0081
#
# Epoch 13701: loss did not improve from 0.00532
# Epoch 13702/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0139 - val_loss: 0.0080
#
# Epoch 13702: loss did not improve from 0.00532
# Epoch 13703/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0311 - val_loss: 0.0081
#
# Epoch 13703: loss did not improve from 0.00532
# Epoch 13704/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0081
#
# Epoch 13704: loss did not improve from 0.00532
# Epoch 13705/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0112 - val_loss: 0.0083
#
# Epoch 13705: loss did not improve from 0.00532
# Epoch 13706/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0191 - val_loss: 0.0087
#
# Epoch 13706: loss did not improve from 0.00532
# Epoch 13707/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0086 - val_loss: 0.0091
#
# Epoch 13707: loss did not improve from 0.00532
# Epoch 13708/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0319 - val_loss: 0.0095
#
# Epoch 13708: loss did not improve from 0.00532
# Epoch 13709/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0259 - val_loss: 0.0101
#
# Epoch 13709: loss did not improve from 0.00532
# Epoch 13710/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0210 - val_loss: 0.0109
#
# Epoch 13710: loss did not improve from 0.00532
# Epoch 13711/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0128 - val_loss: 0.0120
#
# Epoch 13711: loss did not improve from 0.00532
# Epoch 13712/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0139 - val_loss: 0.0128
#
# Epoch 13712: loss did not improve from 0.00532
# Epoch 13713/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0300 - val_loss: 0.0131
#
# Epoch 13713: loss did not improve from 0.00532
# Epoch 13714/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0324 - val_loss: 0.0130
#
# Epoch 13714: loss did not improve from 0.00532
# Epoch 13715/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0157 - val_loss: 0.0132
#
# Epoch 13715: loss did not improve from 0.00532
# Epoch 13716/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0256 - val_loss: 0.0128
#
# Epoch 13716: loss did not improve from 0.00532
# Epoch 13717/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0236 - val_loss: 0.0125
#
# Epoch 13717: loss did not improve from 0.00532
# Epoch 13718/15000
# 12/12 [==============================] - 0s 997us/step - loss: 0.0324 - val_loss: 0.0116
#
# Epoch 13718: loss did not improve from 0.00532
# Epoch 13719/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0158 - val_loss: 0.0105
#
# Epoch 13719: loss did not improve from 0.00532
# Epoch 13720/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0268 - val_loss: 0.0094
#
# Epoch 13720: loss did not improve from 0.00532
# Epoch 13721/15000
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0176 - val_loss: 0.0084

# %%
#load from saved file
file_name = "cnn_lstm_weights_store_all.hdf5"

model_cnn_lstm.load_weights(file_name)
model_cnn_lstm.compile(loss = 'mse', optimizer = 'adam')

#prediction
cnn_lstm_train_prediction = model_cnn_lstm.predict(X_train_series_sub)
cnn_lstm_test_prediction = model_cnn_lstm.predict(X_test_series_sub)

cnn_lstm_train_prediction
# Out:
# array([[4.695902 ],
#        [4.597597 ],
#        [4.690237 ],
#        [4.516028 ],
#        [4.3849134],
#        [4.7063494],
#        [4.4033394],
#        [4.745607 ],
#        [4.687485 ],
#        [4.3956194],
#        [4.684357 ],
#        [4.4685616]], dtype=float32)

# %%
print('Train Error (RMSE):', np.sqrt(mean_squared_error(Y_train, cnn_lstm_train_prediction)))
print('Test Error (RMSE):', np.sqrt(mean_squared_error(Y_test, cnn_lstm_test_prediction)))
# Out:
# Train Error (RMSE): 0.03451280915229757
# Test Error (RMSE): 0.10186385943253083

# %%
#save to csv
date_format = "%Y-%m-%d"
a = datetime.strptime(train['Date'].max(), date_format)
a = a + timedelta(7)

next_date = str(datetime.date(a))
next_sales = np.round(cnn_lstm_train_prediction[len(cnn_lstm_train_prediction) - 1], 2)

dataset = dataset.append(pd.DataFrame({'Store' : '1',
                                       'Item' : '1',
                                       'Date' : next_date,
                                       'Weekly_Sales' : next_sales}))
dataset.tail()

# %%
dataset.to_csv('sales data-set.csv', index = False)
